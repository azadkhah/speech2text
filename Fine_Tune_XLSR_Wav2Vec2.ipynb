# %% [markdown]
# <a href="https://colab.research.google.com/github/azadkhah/speech2text/blob/main/Fine_Tune_XLSR_Wav2Vec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jun 17 18:37:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive

drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive')
# os.chdir('/content/drive/MyDrive/cv-corpus-9.0-2022-04-27')

# %%
# %env LC_ALL=C.UTF-8
# %env LANG=C.UTF-8
# %env TRANSFORMERS_CACHE=/content/cache
# %env HF_DATASETS_CACHE=/content/cache
# %env CUDA_LAUNCH_BLOCKING=1
# Out:
# env: LC_ALL=C.UTF-8
# env: LANG=C.UTF-8
# env: TRANSFORMERS_CACHE=/content/cache
# env: HF_DATASETS_CACHE=/content/cache
# env: CUDA_LAUNCH_BLOCKING=1

# %% [markdown]
# install datasets and transformers

# %%
# %%capture
# !pip install -U datasets
# !pip install -U transformers
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer
# !pip install hazm
# !pip install num2fawords
# !pip install wandb

# %%
from datasets import load_dataset, load_metric

import pandas as pd
import numpy as np

import hazm
from num2fawords import words, ordinal_words
from tqdm import tqdm

from sklearn.model_selection import train_test_split

import os
import string
import six
import re
import glob

# %%
_normalizer = hazm.Normalizer()

chars_to_ignore = [
    ",", "?", ".", "!", "-", ";", ":", '""', "%", "'", '"', "�",
    "#", "!", "؟", "?", "«", "»", "،", "(", ")", "؛", "'ٔ", "٬",'ٔ', ",", "?", 
    ".", "!", "-", ";", ":",'"',"“", "%", "‘", "”", "�", "–", "…", "_", "”", '“', '„',
    'ā', 'š',
#     "ء",
]

# In case of farsi
chars_to_ignore = chars_to_ignore + list(string.ascii_lowercase + string.digits)

chars_to_mapping = {
    'ك': 'ک', 'دِ': 'د', 'بِ': 'ب', 'زِ': 'ز', 'ذِ': 'ذ', 'شِ': 'ش', 'سِ': 'س', 'ى': 'ی',
    'ي': 'ی', 'أ': 'ا', 'ؤ': 'و', "ے": "ی", "ۀ": "ه", "ﭘ": "پ", "ﮐ": "ک", "ﯽ": "ی",
    "ﺎ": "ا", "ﺑ": "ب", "ﺘ": "ت", "ﺧ": "خ", "ﺩ": "د", "ﺱ": "س", "ﻀ": "ض", "ﻌ": "ع",
    "ﻟ": "ل", "ﻡ": "م", "ﻢ": "م", "ﻪ": "ه", "ﻮ": "و", 'ﺍ': "ا", 'ة': "ه",
    'ﯾ': "ی", 'ﯿ': "ی", 'ﺒ': "ب", 'ﺖ': "ت", 'ﺪ': "د", 'ﺮ': "ر", 'ﺴ': "س", 'ﺷ': "ش",
    'ﺸ': "ش", 'ﻋ': "ع", 'ﻤ': "م", 'ﻥ': "ن", 'ﻧ': "ن", 'ﻭ': "و", 'ﺭ': "ر", "ﮔ": "گ",
        
    # "ها": "  ها", "ئ": "ی",
    "۱۴ام": "۱۴ ام",
        
    "a": " ای ", "b": " بی ", "c": " سی ", "d": " دی ", "e": " ایی ", "f": " اف ",
    "g": " جی ", "h": " اچ ", "i": " آی ", "j": " جی ", "k": " کی ", "l": " ال ",
    "m": " ام ", "n": " ان ", "o": " او ", "p": " پی ", "q": " کیو ", "r": " آر ",
    "s": " اس ", "t": " تی ", "u": " یو ", "v": " وی ", "w": " دبلیو ", "x": " اکس ",
    "y": " وای ", "z": " زد ",
    "\u200c": " ", "\u200d": " ", "\u200e": " ", "\u200f": " ", "\ufeff": " ",
}


def multiple_replace(text, chars_to_mapping):
    pattern = "|".join(map(re.escape, chars_to_mapping.keys()))
    return re.sub(pattern, lambda m: chars_to_mapping[m.group()], str(text))

def remove_special_characters(text, chars_to_ignore_regex):
    text = re.sub(chars_to_ignore_regex, '', text).lower() + " "
    return text

def normalizer(text, chars_to_ignore=chars_to_ignore, chars_to_mapping=chars_to_mapping):
    chars_to_ignore_regex = f"""[{"".join(chars_to_ignore)}]"""
    text = text.lower().strip()

    text = _normalizer.normalize(text)
    text = multiple_replace(text, chars_to_mapping)
    text = remove_special_characters(text, chars_to_ignore_regex)
    text = re.sub(" +", " ", text)
    _text = []
    for word in text.split():
        try:
            word = int(word)
            _text.append(words(word))
        except:
            _text.append(word)
            
    text = " ".join(_text) + " "
    text = text.strip()

    if not len(text) > 0:
        return None
    
    return text + " "

# %%
#@title Kaggle Credential

import json

username = "azadkhah" #@param {type: "string"}
api_key = "845b84ed536753a967fc81e3e45e1033" #@param {type: "string"}


if username and api_key:
    token = {"username": username, "key": api_key}

    # !mkdir ~/.kaggle
    # !mkdir /content/.kaggle
    with open('/content/.kaggle/kaggle.json', 'w') as f:
        json.dump(token, f)

    # !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
    # !chmod 600 /root/.kaggle/kaggle.json

    print('Your are ready to use kaggle API!')
# Out:
# Your are ready to use kaggle API!

# %%
# !mkdir -p /content/data/shemo
# !kaggle datasets download mansourehk/shemo-persian-speech-emotion-detection-database
# !unzip shemo-persian-speech-emotion-detection-database.zip -d /content/data/shemo/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/shemo/transcript/final script/F24A22.tra
#   inflating: /content/data/shemo/transcript/final script/F24A23.tra
#   inflating: /content/data/shemo/transcript/final script/F24A24.tra
#   inflating: /content/data/shemo/transcript/final script/F24A25.tra
#   inflating: /content/data/shemo/transcript/final script/F24A26.tra
#   inflating: /content/data/shemo/transcript/final script/F24A27.tra
#   inflating: /content/data/shemo/transcript/final script/F24A28.tra
#   inflating: /content/data/shemo/transcript/final script/F24A29.tra
#   inflating: /content/data/shemo/transcript/final script/F24A30.tra
#   inflating: /content/data/shemo/transcript/final script/F24A31.tra
#   inflating: /content/data/shemo/transcript/final script/F24A32.tra
#   inflating: /content/data/shemo/transcript/final script/F24A33.tra
#   inflating: /content/data/shemo/transcript/final script/F24A34.tra
#   inflating: /content/data/shemo/transcript/final script/F24A35.tra
#   inflating: /content/data/shemo/transcript/final script/F24A36.tra
#   inflating: /content/data/shemo/transcript/final script/F24A37.tra
#   inflating: /content/data/shemo/transcript/final script/F24A38.tra
#   inflating: /content/data/shemo/transcript/final script/F24A39.tra
#   inflating: /content/data/shemo/transcript/final script/F24A40.tra
#   inflating: /content/data/shemo/transcript/final script/F24A41.tra
#   inflating: /content/data/shemo/transcript/final script/F24A42.tra
#   inflating: /content/data/shemo/transcript/final script/F24A43.tra
#   inflating: /content/data/shemo/transcript/final script/F24A44.tra
#   inflating: /content/data/shemo/transcript/final script/F24A45.tra
#   inflating: /content/data/shemo/transcript/final script/F24A46.tra
#   inflating: /content/data/shemo/transcript/final script/F24A47.tra
#   inflating: /content/data/shemo/transcript/final script/F24A48.tra
#   inflating: /content/data/shemo/transcript/final script/F24A49.tra
#   inflating: /content/data/shemo/transcript/final script/F24A50.tra
#   inflating: /content/data/shemo/transcript/final script/F24A51.tra
#   inflating: /content/data/shemo/transcript/final script/F24A52.tra
#   inflating: /content/data/shemo/transcript/final script/F24A53.tra
#   inflating: /content/data/shemo/transcript/final script/F24A54.tra
#   inflating: /content/data/shemo/transcript/final script/F24A55.tra
#   inflating: /content/data/shemo/transcript/final script/F24A56.tra
#   inflating: /content/data/shemo/transcript/final script/F24A57.tra
#   inflating: /content/data/shemo/transcript/final script/F24A58.tra
#   inflating: /content/data/shemo/transcript/final script/F24A59.tra
#   inflating: /content/data/shemo/transcript/final script/F24A60.tra
#   inflating: /content/data/shemo/transcript/final script/F24A61.tra
#   inflating: /content/data/shemo/transcript/final script/F24A62.tra
#   inflating: /content/data/shemo/transcript/final script/F24A63.tra
#   inflating: /content/data/shemo/transcript/final script/F24A64.tra
#   inflating: /content/data/shemo/transcript/final script/F24A65.tra
#   inflating: /content/data/shemo/transcript/final script/F24A66.tra
#   inflating: /content/data/shemo/transcript/final script/F24A67.tra
#   inflating: /content/data/shemo/transcript/final script/F24A68.tra
#   inflating: /content/data/shemo/transcript/final script/F24A69.tra
#   inflating: /content/data/shemo/transcript/final script/F24A70.tra
#   inflating: /content/data/shemo/transcript/final script/F24F01.tra
#   inflating: /content/data/shemo/transcript/final script/F24F02.tra
#   inflating: /content/data/shemo/transcript/final script/F24F03.tra
#   inflating: /content/data/shemo/transcript/final script/F24F04.tra
#   inflating: /content/data/shemo/transcript/final script/F24H01.tra
#   inflating: /content/data/shemo/transcript/final script/F24H02.tra
#   inflating: /content/data/shemo/transcript/final script/F24H03.tra
#   inflating: /content/data/shemo/transcript/final script/F24H04.tra
#   inflating: /content/data/shemo/transcript/final script/F24H05.tra
#   inflating: /content/data/shemo/transcript/final script/F24H06.tra
#   inflating: /content/data/shemo/transcript/final script/F24H07.tra
#   inflating: /content/data/shemo/transcript/final script/F24H08.tra
#   inflating: /content/data/shemo/transcript/final script/F24H09.tra
#   inflating: /content/data/shemo/transcript/final script/F24H10.tra
#   inflating: /content/data/shemo/transcript/final script/F24H11.tra
#   inflating: /content/data/shemo/transcript/final script/F24H12.tra
#   inflating: /content/data/shemo/transcript/final script/F24H13.tra
#   inflating: /content/data/shemo/transcript/final script/F24H14.tra
#   inflating: /content/data/shemo/transcript/final script/F24H15.tra
#   inflating: /content/data/shemo/transcript/final script/F24H16.tra
#   inflating: /content/data/shemo/transcript/final script/F24H17.tra
#   inflating: /content/data/shemo/transcript/final script/F24H18.tra
#   inflating: /content/data/shemo/transcript/final script/F24H19.tra
#   inflating: /content/data/shemo/transcript/final script/F24H20.tra
#   inflating: /content/data/shemo/transcript/final script/F24H21.tra
#   inflating: /content/data/shemo/transcript/final script/F24H22.tra
#   inflating: /content/data/shemo/transcript/final script/F24H23.tra
#   inflating: /content/data/shemo/transcript/final script/F24H24.tra
#   inflating: /content/data/shemo/transcript/final script/F24H25.tra
#   inflating: /content/data/shemo/transcript/final script/F24H26.tra
#   inflating: /content/data/shemo/transcript/final script/F24H27.tra
#   inflating: /content/data/shemo/transcript/final script/F24N01.tra
#   inflating: /content/data/shemo/transcript/final script/F24N02.tra
#   inflating: /content/data/shemo/transcript/final script/F24N03.tra
#   inflating: /content/data/shemo/transcript/final script/F24N04.tra
#   inflating: /content/data/shemo/transcript/final script/F24N05.tra
#   inflating: /content/data/shemo/transcript/final script/F24N06.tra
#   inflating: /content/data/shemo/transcript/final script/F24N07.tra
#   inflating: /content/data/shemo/transcript/final script/F24N08.tra
#   inflating: /content/data/shemo/transcript/final script/F24N09.tra
#   inflating: /content/data/shemo/transcript/final script/F24N10.tra
#   inflating: /content/data/shemo/transcript/final script/F24N11.tra
#   inflating: /content/data/shemo/transcript/final script/F24N12.tra
#   inflating: /content/data/shemo/transcript/final script/F24N13.tra
#   inflating: /content/data/shemo/transcript/final script/F24N14.tra
#   inflating: /content/data/shemo/transcript/final script/F24N15.tra
#   inflating: /content/data/shemo/transcript/final script/F24N16.tra
#   inflating: /content/data/shemo/transcript/final script/F24N17.tra
#   inflating: /content/data/shemo/transcript/final script/F24N18.tra
#   inflating: /content/data/shemo/transcript/final script/F24N19.tra
#   inflating: /content/data/shemo/transcript/final script/F24N20.tra
#   inflating: /content/data/shemo/transcript/final script/F24S01.tra
#   inflating: /content/data/shemo/transcript/final script/F24S02.tra
#   inflating: /content/data/shemo/transcript/final script/F24S03.tra
#   inflating: /content/data/shemo/transcript/final script/F24S04.tra
#   inflating: /content/data/shemo/transcript/final script/F24S05.tra
#   inflating: /content/data/shemo/transcript/final script/F24S06.tra
#   inflating: /content/data/shemo/transcript/final script/F24S07.tra
#   inflating: /content/data/shemo/transcript/final script/F24S08.tra
#   inflating: /content/data/shemo/transcript/final script/F24S09.tra
#   inflating: /content/data/shemo/transcript/final script/F24S10.tra
#   inflating: /content/data/shemo/transcript/final script/F24S11.tra
#   inflating: /content/data/shemo/transcript/final script/F24S12.tra
#   inflating: /content/data/shemo/transcript/final script/F24S13.tra
#   inflating: /content/data/shemo/transcript/final script/F24S14.tra
#   inflating: /content/data/shemo/transcript/final script/F24S15.tra
#   inflating: /content/data/shemo/transcript/final script/F24W01.tra
#   inflating: /content/data/shemo/transcript/final script/F24W02.tra
#   inflating: /content/data/shemo/transcript/final script/F24W03.tra
#   inflating: /content/data/shemo/transcript/final script/F24W04.tra
#   inflating: /content/data/shemo/transcript/final script/F24W05.tra
#   inflating: /content/data/shemo/transcript/final script/F24W06.tra
#   inflating: /content/data/shemo/transcript/final script/F24W07.tra
#   inflating: /content/data/shemo/transcript/final script/F24W08.tra
#   inflating: /content/data/shemo/transcript/final script/F24W09.tra
#   inflating: /content/data/shemo/transcript/final script/F24W10.tra
#   inflating: /content/data/shemo/transcript/final script/F24W11.tra
#   inflating: /content/data/shemo/transcript/final script/F24W12.tra
#   inflating: /content/data/shemo/transcript/final script/F24W13.tra
#   inflating: /content/data/shemo/transcript/final script/F24W14.tra
#   inflating: /content/data/shemo/transcript/final script/F24W15.tra
#   inflating: /content/data/shemo/transcript/final script/F24W16.tra
#   inflating: /content/data/shemo/transcript/final script/F24W17.tra
#   inflating: /content/data/shemo/transcript/final script/F24W18.tra
#   inflating: /content/data/shemo/transcript/final script/F24W19.tra
#   inflating: /content/data/shemo/transcript/final script/F24W20.tra
#   inflating: /content/data/shemo/transcript/final script/F24W21.tra
#   inflating: /content/data/shemo/transcript/final script/F24W22.tra
#   inflating: /content/data/shemo/transcript/final script/F24W23.tra
#   inflating: /content/data/shemo/transcript/final script/F24W24.tra
#   inflating: /content/data/shemo/transcript/final script/F25A01.tra
#   inflating: /content/data/shemo/transcript/final script/F25A02.tra
#   inflating: /content/data/shemo/transcript/final script/F25A03.tra
#   inflating: /content/data/shemo/transcript/final script/F25A04.tra
#   inflating: /content/data/shemo/transcript/final script/F25A05.tra
#   inflating: /content/data/shemo/transcript/final script/F25A06.tra
#   inflating: /content/data/shemo/transcript/final script/F25A07.tra
#   inflating: /content/data/shemo/transcript/final script/F25N01.tra
#   inflating: /content/data/shemo/transcript/final script/F25N02.tra
#   inflating: /content/data/shemo/transcript/final script/F25N03.tra
#   inflating: /content/data/shemo/transcript/final script/F25N04.tra
#   inflating: /content/data/shemo/transcript/final script/F26F01.tra
#   inflating: /content/data/shemo/transcript/final script/F26N01.tra
#   inflating: /content/data/shemo/transcript/final script/F26N02.tra
#   inflating: /content/data/shemo/transcript/final script/F26N03.tra
#   inflating: /content/data/shemo/transcript/final script/F26N04.tra
#   inflating: /content/data/shemo/transcript/final script/F26N05.tra
#   inflating: /content/data/shemo/transcript/final script/F26N06.tra
#   inflating: /content/data/shemo/transcript/final script/F26S01.tra
#   inflating: /content/data/shemo/transcript/final script/F26S02.tra
#   inflating: /content/data/shemo/transcript/final script/F26S03.tra
#   inflating: /content/data/shemo/transcript/final script/F27A01.tra
#   inflating: /content/data/shemo/transcript/final script/F27A02.tra
#   inflating: /content/data/shemo/transcript/final script/F27A03.tra
#   inflating: /content/data/shemo/transcript/final script/F27H01.tra
#   inflating: /content/data/shemo/transcript/final script/F27N01.tra
#   inflating: /content/data/shemo/transcript/final script/F28A01.tra
#   inflating: /content/data/shemo/transcript/final script/F28A02.tra
#   inflating: /content/data/shemo/transcript/final script/F28A03.tra
#   inflating: /content/data/shemo/transcript/final script/F28A04.tra
#   inflating: /content/data/shemo/transcript/final script/F28A05.tra
#   inflating: /content/data/shemo/transcript/final script/F28A06.tra
#   inflating: /content/data/shemo/transcript/final script/F28A07.tra
#   inflating: /content/data/shemo/transcript/final script/F28A08.tra
#   inflating: /content/data/shemo/transcript/final script/F28A09.tra
#   inflating: /content/data/shemo/transcript/final script/F28A10.tra
#   inflating: /content/data/shemo/transcript/final script/F28A11.tra
#   inflating: /content/data/shemo/transcript/final script/F28A12.tra
#   inflating: /content/data/shemo/transcript/final script/F28A13.tra
#   inflating: /content/data/shemo/transcript/final script/F28A14.tra
#   inflating: /content/data/shemo/transcript/final script/F28A15.tra
#   inflating: /content/data/shemo/transcript/final script/F28A16.tra
#   inflating: /content/data/shemo/transcript/final script/F28A17.tra
#   inflating: /content/data/shemo/transcript/final script/F28A18.tra
#   inflating: /content/data/shemo/transcript/final script/F28A19.tra
#   inflating: /content/data/shemo/transcript/final script/F28A20.tra
#   inflating: /content/data/shemo/transcript/final script/F28A21.tra
#   inflating: /content/data/shemo/transcript/final script/F28A22.tra
#   inflating: /content/data/shemo/transcript/final script/F28A23.tra
#   inflating: /content/data/shemo/transcript/final script/F28A24.tra
#   inflating: /content/data/shemo/transcript/final script/F28A25.tra
#   inflating: /content/data/shemo/transcript/final script/F28A26.tra
#   inflating: /content/data/shemo/transcript/final script/F28H01.tra
#   inflating: /content/data/shemo/transcript/final script/F28N01.tra
#   inflating: /content/data/shemo/transcript/final script/F28N02.tra
#   inflating: /content/data/shemo/transcript/final script/F28N03.tra
#   inflating: /content/data/shemo/transcript/final script/F28N04.tra
#   inflating: /content/data/shemo/transcript/final script/F28N05.tra
#   inflating: /content/data/shemo/transcript/final script/F28N06.tra
#   inflating: /content/data/shemo/transcript/final script/F28N07.tra
#   inflating: /content/data/shemo/transcript/final script/F28S01.tra
#   inflating: /content/data/shemo/transcript/final script/F28S02.tra
#   inflating: /content/data/shemo/transcript/final script/F28S03.tra
#   inflating: /content/data/shemo/transcript/final script/F28S04.tra
#   inflating: /content/data/shemo/transcript/final script/F28S05.tra
#   inflating: /content/data/shemo/transcript/final script/F28S06.tra
#   inflating: /content/data/shemo/transcript/final script/F29H01.tra
#   inflating: /content/data/shemo/transcript/final script/F29N01.tra
#   inflating: /content/data/shemo/transcript/final script/F29N02.tra
#   inflating: /content/data/shemo/transcript/final script/F29N03.tra
#   inflating: /content/data/shemo/transcript/final script/F29N04.tra
#   inflating: /content/data/shemo/transcript/final script/F29N05.tra
#   inflating: /content/data/shemo/transcript/final script/F29N06.tra
#   inflating: /content/data/shemo/transcript/final script/F29N07.tra
#   inflating: /content/data/shemo/transcript/final script/F29N08.tra
#   inflating: /content/data/shemo/transcript/final script/F29N09.tra
#   inflating: /content/data/shemo/transcript/final script/F29N10.tra
#   inflating: /content/data/shemo/transcript/final script/F29W01.tra
#   inflating: /content/data/shemo/transcript/final script/F30A01.tra
#   inflating: /content/data/shemo/transcript/final script/F30A02.tra
#   inflating: /content/data/shemo/transcript/final script/F30A03.tra
#   inflating: /content/data/shemo/transcript/final script/F30A04.tra
#   inflating: /content/data/shemo/transcript/final script/F30A05.tra
#   inflating: /content/data/shemo/transcript/final script/F30A06.tra
#   inflating: /content/data/shemo/transcript/final script/F30A07.tra
#   inflating: /content/data/shemo/transcript/final script/F30A08.tra
#   inflating: /content/data/shemo/transcript/final script/F30F01.tra
#   inflating: /content/data/shemo/transcript/final script/F30H01.tra
#   inflating: /content/data/shemo/transcript/final script/F30H02.tra
#   inflating: /content/data/shemo/transcript/final script/F30H03.tra
#   inflating: /content/data/shemo/transcript/final script/F30H04.tra
#   inflating: /content/data/shemo/transcript/final script/F30H05.tra
#   inflating: /content/data/shemo/transcript/final script/F30H06.tra
#   inflating: /content/data/shemo/transcript/final script/F30N01.tra
#   inflating: /content/data/shemo/transcript/final script/F30N02.tra
#   inflating: /content/data/shemo/transcript/final script/F30N03.tra
#   inflating: /content/data/shemo/transcript/final script/F30N04.tra
#   inflating: /content/data/shemo/transcript/final script/F30N05.tra
#   inflating: /content/data/shemo/transcript/final script/F30N06.tra
#   inflating: /content/data/shemo/transcript/final script/F30N07.tra
#   inflating: /content/data/shemo/transcript/final script/F30N08.tra
#   inflating: /content/data/shemo/transcript/final script/F30S01.tra
#   inflating: /content/data/shemo/transcript/final script/F30S02.tra
#   inflating: /content/data/shemo/transcript/final script/F30S03.tra
#   inflating: /content/data/shemo/transcript/final script/F30S04.tra
#   inflating: /content/data/shemo/transcript/final script/F30S05.tra
#   inflating: /content/data/shemo/transcript/final script/F30S06.tra
#   inflating: /content/data/shemo/transcript/final script/F30S07.tra
#   inflating: /content/data/shemo/transcript/final script/F30S08.tra
#   inflating: /content/data/shemo/transcript/final script/F30S09.tra
#   inflating: /content/data/shemo/transcript/final script/F30S10.tra
#   inflating: /content/data/shemo/transcript/final script/F30W01.tra
#   inflating: /content/data/shemo/transcript/final script/F31A01.tra
#   inflating: /content/data/shemo/transcript/final script/F31A02.tra
#   inflating: /content/data/shemo/transcript/final script/F31A03.tra
#   inflating: /content/data/shemo/transcript/final script/F31A04.tra
#   inflating: /content/data/shemo/transcript/final script/F31A05.tra
#   inflating: /content/data/shemo/transcript/final script/F31A06.tra
#   inflating: /content/data/shemo/transcript/final script/F31A07.tra
#   inflating: /content/data/shemo/transcript/final script/F31A08.tra
#   inflating: /content/data/shemo/transcript/final script/F31A09.tra
#   inflating: /content/data/shemo/transcript/final script/F31A10.tra
#   inflating: /content/data/shemo/transcript/final script/F31A11.tra
#   inflating: /content/data/shemo/transcript/final script/F31S01.tra
#   inflating: /content/data/shemo/transcript/final script/M01H01.tra
#   inflating: /content/data/shemo/transcript/final script/M01N01.tra
#   inflating: /content/data/shemo/transcript/final script/M01N02.tra
#   inflating: /content/data/shemo/transcript/final script/M01W01.tra
#   inflating: /content/data/shemo/transcript/final script/M02A01.tra
#   inflating: /content/data/shemo/transcript/final script/M02A02.tra
#   inflating: /content/data/shemo/transcript/final script/M02A03.tra
#   inflating: /content/data/shemo/transcript/final script/M02A04.tra
#   inflating: /content/data/shemo/transcript/final script/M02A05.tra
#   inflating: /content/data/shemo/transcript/final script/M02A06.tra
#   inflating: /content/data/shemo/transcript/final script/M02A07.tra
#   inflating: /content/data/shemo/transcript/final script/M02A08.tra
#   inflating: /content/data/shemo/transcript/final script/M02A09.tra
#   inflating: /content/data/shemo/transcript/final script/M02A10.tra
#   inflating: /content/data/shemo/transcript/final script/M02A11.tra
#   inflating: /content/data/shemo/transcript/final script/M02A12.tra
#   inflating: /content/data/shemo/transcript/final script/M02A13.tra
#   inflating: /content/data/shemo/transcript/final script/M02A14.tra
#   inflating: /content/data/shemo/transcript/final script/M02A15.tra
#   inflating: /content/data/shemo/transcript/final script/M02A16.tra
#   inflating: /content/data/shemo/transcript/final script/M02A17.tra
#   inflating: /content/data/shemo/transcript/final script/M02A18.tra
#   inflating: /content/data/shemo/transcript/final script/M02A19.tra
#   inflating: /content/data/shemo/transcript/final script/M02A20.tra
#   inflating: /content/data/shemo/transcript/final script/M02A21.tra
#   inflating: /content/data/shemo/transcript/final script/M02A22.tra
#   inflating: /content/data/shemo/transcript/final script/M02A23.tra
#   inflating: /content/data/shemo/transcript/final script/M02A24.tra
#   inflating: /content/data/shemo/transcript/final script/M02A25.tra
#   inflating: /content/data/shemo/transcript/final script/M02A26.tra
#   inflating: /content/data/shemo/transcript/final script/M02A27.tra
#   inflating: /content/data/shemo/transcript/final script/M02A28.tra
#   inflating: /content/data/shemo/transcript/final script/M02H01.tra
#   inflating: /content/data/shemo/transcript/final script/M02H02.tra
#   inflating: /content/data/shemo/transcript/final script/M02H03.tra
#   inflating: /content/data/shemo/transcript/final script/M02H04.tra
#   inflating: /content/data/shemo/transcript/final script/M02N01.tra
#   inflating: /content/data/shemo/transcript/final script/M02N02.tra
#   inflating: /content/data/shemo/transcript/final script/M02N03.tra
#   inflating: /content/data/shemo/transcript/final script/M02N04.tra
#   inflating: /content/data/shemo/transcript/final script/M02N05.tra
#   inflating: /content/data/shemo/transcript/final script/M02N06.tra
#   inflating: /content/data/shemo/transcript/final script/M02N07.tra
#   inflating: /content/data/shemo/transcript/final script/M02N08.tra
#   inflating: /content/data/shemo/transcript/final script/M02N09.tra
#   inflating: /content/data/shemo/transcript/final script/M02N10.tra
#   inflating: /content/data/shemo/transcript/final script/M02N11.tra
#   inflating: /content/data/shemo/transcript/final script/M02N12.tra
#   inflating: /content/data/shemo/transcript/final script/M02N13.tra
#   inflating: /content/data/shemo/transcript/final script/M02N14.tra
#   inflating: /content/data/shemo/transcript/final script/M02N15.tra
#   inflating: /content/data/shemo/transcript/final script/M02N16.tra
#   inflating: /content/data/shemo/transcript/final script/M02N17.tra
#   inflating: /content/data/shemo/transcript/final script/M02N18.tra
#   inflating: /content/data/shemo/transcript/final script/M02N19.tra
#   inflating: /content/data/shemo/transcript/final script/M02S01.tra
#   inflating: /content/data/shemo/transcript/final script/M02S02.tra
#   inflating: /content/data/shemo/transcript/final script/M03A01.tra
#   inflating: /content/data/shemo/transcript/final script/M03A02.tra
#   inflating: /content/data/shemo/transcript/final script/M03A03.tra
#   inflating: /content/data/shemo/transcript/final script/M03A04.tra
#   inflating: /content/data/shemo/transcript/final script/M03A05.tra
#   inflating: /content/data/shemo/transcript/final script/M03A06.tra
#   inflating: /content/data/shemo/transcript/final script/M03A07.tra
#   inflating: /content/data/shemo/transcript/final script/M03A08.tra
#   inflating: /content/data/shemo/transcript/final script/M03A09.tra
#   inflating: /content/data/shemo/transcript/final script/M03A10.tra
#   inflating: /content/data/shemo/transcript/final script/M03A11.tra
#   inflating: /content/data/shemo/transcript/final script/M03A12.tra
#   inflating: /content/data/shemo/transcript/final script/M03A13.tra
#   inflating: /content/data/shemo/transcript/final script/M03A14.tra
#   inflating: /content/data/shemo/transcript/final script/M03A15.tra
#   inflating: /content/data/shemo/transcript/final script/M03A16.tra
#   inflating: /content/data/shemo/transcript/final script/M03A17.tra
#   inflating: /content/data/shemo/transcript/final script/M03A18.tra
#   inflating: /content/data/shemo/transcript/final script/M03A19.tra
#   inflating: /content/data/shemo/transcript/final script/M03A20.tra
#   inflating: /content/data/shemo/transcript/final script/M03A21.tra
#   inflating: /content/data/shemo/transcript/final script/M03A22.tra
#   inflating: /content/data/shemo/transcript/final script/M03A23.tra
#   inflating: /content/data/shemo/transcript/final script/M03A24.tra
#   inflating: /content/data/shemo/transcript/final script/M03A25.tra
#   inflating: /content/data/shemo/transcript/final script/M03A26.tra
#   inflating: /content/data/shemo/transcript/final script/M03A27.tra
#   inflating: /content/data/shemo/transcript/final script/M03A28.tra
#   inflating: /content/data/shemo/transcript/final script/M03A29.tra
#   inflating: /content/data/shemo/transcript/final script/M03A30.tra
#   inflating: /content/data/shemo/transcript/final script/M03A31.tra
#   inflating: /content/data/shemo/transcript/final script/M03A32.tra
#   inflating: /content/data/shemo/transcript/final script/M03A33.tra
#   inflating: /content/data/shemo/transcript/final script/M03A34.tra
#   inflating: /content/data/shemo/transcript/final script/M03A35.tra
#   inflating: /content/data/shemo/transcript/final script/M03A36.tra
#   inflating: /content/data/shemo/transcript/final script/M03A37.tra
#   inflating: /content/data/shemo/transcript/final script/M03A38.tra
#   inflating: /content/data/shemo/transcript/final script/M03A39.tra
#   inflating: /content/data/shemo/transcript/final script/M03A40.tra
#   inflating: /content/data/shemo/transcript/final script/M03A41.tra
#   inflating: /content/data/shemo/transcript/final script/M03A42.tra
#   inflating: /content/data/shemo/transcript/final script/M03A43.tra
#   inflating: /content/data/shemo/transcript/final script/M03A44.tra
#   inflating: /content/data/shemo/transcript/final script/M03A45.tra
#   inflating: /content/data/shemo/transcript/final script/M03A46.tra
#   inflating: /content/data/shemo/transcript/final script/M03A47.tra
#   inflating: /content/data/shemo/transcript/final script/M03A48.tra
#   inflating: /content/data/shemo/transcript/final script/M03A49.tra
#   inflating: /content/data/shemo/transcript/final script/M03F01.tra
#   inflating: /content/data/shemo/transcript/final script/M03F02.tra
#   inflating: /content/data/shemo/transcript/final script/M03H01.tra
#   inflating: /content/data/shemo/transcript/final script/M03H02.tra
#   inflating: /content/data/shemo/transcript/final script/M03N01.tra
#   inflating: /content/data/shemo/transcript/final script/M03N02.tra
#   inflating: /content/data/shemo/transcript/final script/M03N03.tra
#   inflating: /content/data/shemo/transcript/final script/M03N04.tra
#   inflating: /content/data/shemo/transcript/final script/M03N05.tra
#   inflating: /content/data/shemo/transcript/final script/M03N06.tra
#   inflating: /content/data/shemo/transcript/final script/M03N07.tra
#   inflating: /content/data/shemo/transcript/final script/M03N08.tra
#   inflating: /content/data/shemo/transcript/final script/M03N09.tra
#   inflating: /content/data/shemo/transcript/final script/M03S01.tra
#   inflating: /content/data/shemo/transcript/final script/M03S02.tra
#   inflating: /content/data/shemo/transcript/final script/M03S03.tra
#   inflating: /content/data/shemo/transcript/final script/M03S04.tra
#   inflating: /content/data/shemo/transcript/final script/M03S05.tra
#   inflating: /content/data/shemo/transcript/final script/M03S06.tra
#   inflating: /content/data/shemo/transcript/final script/M03S07.tra
#   inflating: /content/data/shemo/transcript/final script/M03S08.tra
#   inflating: /content/data/shemo/transcript/final script/M03S09.tra
#   inflating: /content/data/shemo/transcript/final script/M03S10.tra
#   inflating: /content/data/shemo/transcript/final script/M03S11.tra
#   inflating: /content/data/shemo/transcript/final script/M03S12.tra
#   inflating: /content/data/shemo/transcript/final script/M03S13.tra
#   inflating: /content/data/shemo/transcript/final script/M03S14.tra
#   inflating: /content/data/shemo/transcript/final script/M03S15.tra
#   inflating: /content/data/shemo/transcript/final script/M03S16.tra
#   inflating: /content/data/shemo/transcript/final script/M03S17.tra
#   inflating: /content/data/shemo/transcript/final script/M03S18.tra
#   inflating: /content/data/shemo/transcript/final script/M03S19.tra
#   inflating: /content/data/shemo/transcript/final script/M03S20.tra
#   inflating: /content/data/shemo/transcript/final script/M03W01.tra
#   inflating: /content/data/shemo/transcript/final script/M03W02.tra
#   inflating: /content/data/shemo/transcript/final script/M03W03.tra
#   inflating: /content/data/shemo/transcript/final script/M03W04.tra
#   inflating: /content/data/shemo/transcript/final script/M03W05.tra
#   inflating: /content/data/shemo/transcript/final script/M03W06.tra
#   inflating: /content/data/shemo/transcript/final script/M03W07.tra
#   inflating: /content/data/shemo/transcript/final script/M04A01.tra
#   inflating: /content/data/shemo/transcript/final script/M04A02.tra
#   inflating: /content/data/shemo/transcript/final script/M04A03.tra
#   inflating: /content/data/shemo/transcript/final script/M04A04.tra
#   inflating: /content/data/shemo/transcript/final script/M04A05.tra
#   inflating: /content/data/shemo/transcript/final script/M04A06.tra
#   inflating: /content/data/shemo/transcript/final script/M04A07.tra
#   inflating: /content/data/shemo/transcript/final script/M04A08.tra
#   inflating: /content/data/shemo/transcript/final script/M04A09.tra
#   inflating: /content/data/shemo/transcript/final script/M04A10.tra
#   inflating: /content/data/shemo/transcript/final script/M04A11.tra
#   inflating: /content/data/shemo/transcript/final script/M04A12.tra
#   inflating: /content/data/shemo/transcript/final script/M04H01.tra
#   inflating: /content/data/shemo/transcript/final script/M04H02.tra
#   inflating: /content/data/shemo/transcript/final script/M04N01.tra
#   inflating: /content/data/shemo/transcript/final script/M04N02.tra
#   inflating: /content/data/shemo/transcript/final script/M04N03.tra
#   inflating: /content/data/shemo/transcript/final script/M04N04.tra
#   inflating: /content/data/shemo/transcript/final script/M04N05.tra
#   inflating: /content/data/shemo/transcript/final script/M04N06.tra
#   inflating: /content/data/shemo/transcript/final script/M04N07.tra
#   inflating: /content/data/shemo/transcript/final script/M04N08.tra
#   inflating: /content/data/shemo/transcript/final script/M04N09.tra
#   inflating: /content/data/shemo/transcript/final script/M04N10.tra
#   inflating: /content/data/shemo/transcript/final script/M04N11.tra
#   inflating: /content/data/shemo/transcript/final script/M04N12.tra
#   inflating: /content/data/shemo/transcript/final script/M04N13.tra
#   inflating: /content/data/shemo/transcript/final script/M04N14.tra
#   inflating: /content/data/shemo/transcript/final script/M04N15.tra
#   inflating: /content/data/shemo/transcript/final script/M04N16.tra
#   inflating: /content/data/shemo/transcript/final script/M04N17.tra
#   inflating: /content/data/shemo/transcript/final script/M04N18.tra
#   inflating: /content/data/shemo/transcript/final script/M04N19.tra
#   inflating: /content/data/shemo/transcript/final script/M04N20.tra
#   inflating: /content/data/shemo/transcript/final script/M04N21.tra
#   inflating: /content/data/shemo/transcript/final script/M04N22.tra
#   inflating: /content/data/shemo/transcript/final script/M04N23.tra
#   inflating: /content/data/shemo/transcript/final script/M04N24.tra
#   inflating: /content/data/shemo/transcript/final script/M04N25.tra
#   inflating: /content/data/shemo/transcript/final script/M04N26.tra
#   inflating: /content/data/shemo/transcript/final script/M04N27.tra
#   inflating: /content/data/shemo/transcript/final script/M04N28.tra
#   inflating: /content/data/shemo/transcript/final script/M04N29.tra
#   inflating: /content/data/shemo/transcript/final script/M04N30.tra
#   inflating: /content/data/shemo/transcript/final script/M04N31.tra
#   inflating: /content/data/shemo/transcript/final script/M04N32.tra
#   inflating: /content/data/shemo/transcript/final script/M04N33.tra
#   inflating: /content/data/shemo/transcript/final script/M04N34.tra
#   inflating: /content/data/shemo/transcript/final script/M04N35.tra
#   inflating: /content/data/shemo/transcript/final script/M04N36.tra
#   inflating: /content/data/shemo/transcript/final script/M04N37.tra
#   inflating: /content/data/shemo/transcript/final script/M04N38.tra
#   inflating: /content/data/shemo/transcript/final script/M04N39.tra
#   inflating: /content/data/shemo/transcript/final script/M04N40.tra
#   inflating: /content/data/shemo/transcript/final script/M04N41.tra
#   inflating: /content/data/shemo/transcript/final script/M04N42.tra
#   inflating: /content/data/shemo/transcript/final script/M04N43.tra
#   inflating: /content/data/shemo/transcript/final script/M04N44.tra
#   inflating: /content/data/shemo/transcript/final script/M04N45.tra
#   inflating: /content/data/shemo/transcript/final script/M04N46.tra
#   inflating: /content/data/shemo/transcript/final script/M04N47.tra
#   inflating: /content/data/shemo/transcript/final script/M04N48.tra
#   inflating: /content/data/shemo/transcript/final script/M04N49.tra
#   inflating: /content/data/shemo/transcript/final script/M04N50.tra
#   inflating: /content/data/shemo/transcript/final script/M04N51.tra
#   inflating: /content/data/shemo/transcript/final script/M04N52.tra
#   inflating: /content/data/shemo/transcript/final script/M04N53.tra
#   inflating: /content/data/shemo/transcript/final script/M04N54.tra
#   inflating: /content/data/shemo/transcript/final script/M04N55.tra
#   inflating: /content/data/shemo/transcript/final script/M04N56.tra
#   inflating: /content/data/shemo/transcript/final script/M04N57.tra
#   inflating: /content/data/shemo/transcript/final script/M04N58.tra
#   inflating: /content/data/shemo/transcript/final script/M04N59.tra
#   inflating: /content/data/shemo/transcript/final script/M04N60.tra
#   inflating: /content/data/shemo/transcript/final script/M04N61.tra
#   inflating: /content/data/shemo/transcript/final script/M04N62.tra
#   inflating: /content/data/shemo/transcript/final script/M04N63.tra
#   inflating: /content/data/shemo/transcript/final script/M04N64.tra
#   inflating: /content/data/shemo/transcript/final script/M04N65.tra
#   inflating: /content/data/shemo/transcript/final script/M04N66.tra
#   inflating: /content/data/shemo/transcript/final script/M04N67.tra
#   inflating: /content/data/shemo/transcript/final script/M04N68.tra
#   inflating: /content/data/shemo/transcript/final script/M04N69.tra
#   inflating: /content/data/shemo/transcript/final script/M04N70.tra
#   inflating: /content/data/shemo/transcript/final script/M04N71.tra
#   inflating: /content/data/shemo/transcript/final script/M04N72.tra
#   inflating: /content/data/shemo/transcript/final script/M04N73.tra
#   inflating: /content/data/shemo/transcript/final script/M04N74.tra
#   inflating: /content/data/shemo/transcript/final script/M04N75.tra
#   inflating: /content/data/shemo/transcript/final script/M04N76.tra
#   inflating: /content/data/shemo/transcript/final script/M04N77.tra
#   inflating: /content/data/shemo/transcript/final script/M04N78.tra
#   inflating: /content/data/shemo/transcript/final script/M04N79.tra
#   inflating: /content/data/shemo/transcript/final script/M04N80.tra
#   inflating: /content/data/shemo/transcript/final script/M04N81.tra
#   inflating: /content/data/shemo/transcript/final script/M04N82.tra
#   inflating: /content/data/shemo/transcript/final script/M04S01.tra
#   inflating: /content/data/shemo/transcript/final script/M04S02.tra
#   inflating: /content/data/shemo/transcript/final script/M04S03.tra
#   inflating: /content/data/shemo/transcript/final script/M04S04.tra
#   inflating: /content/data/shemo/transcript/final script/M04S05.tra
#   inflating: /content/data/shemo/transcript/final script/M04S06.tra
#   inflating: /content/data/shemo/transcript/final script/M04S07.tra
#   inflating: /content/data/shemo/transcript/final script/M04S08.tra
#   inflating: /content/data/shemo/transcript/final script/M04S09.tra
#   inflating: /content/data/shemo/transcript/final script/M04W01.tra
#   inflating: /content/data/shemo/transcript/final script/M04W02.tra
#   inflating: /content/data/shemo/transcript/final script/M05A01.tra
#   inflating: /content/data/shemo/transcript/final script/M05A02.tra
#   inflating: /content/data/shemo/transcript/final script/M05A03.tra
#   inflating: /content/data/shemo/transcript/final script/M05A04.tra
#   inflating: /content/data/shemo/transcript/final script/M05A05.tra
#   inflating: /content/data/shemo/transcript/final script/M05A06.tra
#   inflating: /content/data/shemo/transcript/final script/M05A07.tra
#   inflating: /content/data/shemo/transcript/final script/M05A08.tra
#   inflating: /content/data/shemo/transcript/final script/M05A09.tra
#   inflating: /content/data/shemo/transcript/final script/M05A10.tra
#   inflating: /content/data/shemo/transcript/final script/M05A11.tra
#   inflating: /content/data/shemo/transcript/final script/M05A14.tra
#   inflating: /content/data/shemo/transcript/final script/M05A15.tra
#   inflating: /content/data/shemo/transcript/final script/M05F01.tra
#   inflating: /content/data/shemo/transcript/final script/M05H01.tra
#   inflating: /content/data/shemo/transcript/final script/M05H02.tra
#   inflating: /content/data/shemo/transcript/final script/M05N01.tra
#   inflating: /content/data/shemo/transcript/final script/M05N02.tra
#   inflating: /content/data/shemo/transcript/final script/M05N03.tra
#   inflating: /content/data/shemo/transcript/final script/M05N04.tra
#   inflating: /content/data/shemo/transcript/final script/M05N11.tra
#   inflating: /content/data/shemo/transcript/final script/M05N12.tra
#   inflating: /content/data/shemo/transcript/final script/M05N13.tra
#   inflating: /content/data/shemo/transcript/final script/M05N14.tra
#   inflating: /content/data/shemo/transcript/final script/M05N15.tra
#   inflating: /content/data/shemo/transcript/final script/M05N16.tra
#   inflating: /content/data/shemo/transcript/final script/M05N17.tra
#   inflating: /content/data/shemo/transcript/final script/M05N18.tra
#   inflating: /content/data/shemo/transcript/final script/M05N19.tra
#   inflating: /content/data/shemo/transcript/final script/M05N20.tra
#   inflating: /content/data/shemo/transcript/final script/M05N21.tra
#   inflating: /content/data/shemo/transcript/final script/M05N22.tra
#   inflating: /content/data/shemo/transcript/final script/M05N23.tra
#   inflating: /content/data/shemo/transcript/final script/M05N24.tra
#   inflating: /content/data/shemo/transcript/final script/M05N25.tra
#   inflating: /content/data/shemo/transcript/final script/M05N26.tra
#   inflating: /content/data/shemo/transcript/final script/M05S01.tra
#   inflating: /content/data/shemo/transcript/final script/M05S02.tra
#   inflating: /content/data/shemo/transcript/final script/M05S03.tra
#   inflating: /content/data/shemo/transcript/final script/M05S04.tra
#   inflating: /content/data/shemo/transcript/final script/M05S05.tra
#   inflating: /content/data/shemo/transcript/final script/M05S06.tra
#   inflating: /content/data/shemo/transcript/final script/M05S07.tra
#   inflating: /content/data/shemo/transcript/final script/M05S08.tra
#   inflating: /content/data/shemo/transcript/final script/M05S09.tra
#   inflating: /content/data/shemo/transcript/final script/M05S10.tra
#   inflating: /content/data/shemo/transcript/final script/M05S11.tra
#   inflating: /content/data/shemo/transcript/final script/M05S12.tra
#   inflating: /content/data/shemo/transcript/final script/M05S13.tra
#   inflating: /content/data/shemo/transcript/final script/M05S21.tra
#   inflating: /content/data/shemo/transcript/final script/M05W01.tra
#   inflating: /content/data/shemo/transcript/final script/M05W02.tra
#   inflating: /content/data/shemo/transcript/final script/M05W04.tra
#   inflating: /content/data/shemo/transcript/final script/M06A01.tra
#   inflating: /content/data/shemo/transcript/final script/M06A02.tra
#   inflating: /content/data/shemo/transcript/final script/M06N01.tra
#   inflating: /content/data/shemo/transcript/final script/M06N02.tra
#   inflating: /content/data/shemo/transcript/final script/M06N03.tra
#   inflating: /content/data/shemo/transcript/final script/M06N04.tra
#   inflating: /content/data/shemo/transcript/final script/M06N05.tra
#   inflating: /content/data/shemo/transcript/final script/M06N06.tra
#   inflating: /content/data/shemo/transcript/final script/M06S01.tra
#   inflating: /content/data/shemo/transcript/final script/M06S02.tra
#   inflating: /content/data/shemo/transcript/final script/M06S03.tra
#   inflating: /content/data/shemo/transcript/final script/M06S04.tra
#   inflating: /content/data/shemo/transcript/final script/M06S05.tra
#   inflating: /content/data/shemo/transcript/final script/M06S06.tra
#   inflating: /content/data/shemo/transcript/final script/M06S07.tra
#   inflating: /content/data/shemo/transcript/final script/M06W01.tra
#   inflating: /content/data/shemo/transcript/final script/M07F01.tra
#   inflating: /content/data/shemo/transcript/final script/M07F02.tra
#   inflating: /content/data/shemo/transcript/final script/M07F03.tra
#   inflating: /content/data/shemo/transcript/final script/M07F04.tra
#   inflating: /content/data/shemo/transcript/final script/M07F05.tra
#   inflating: /content/data/shemo/transcript/final script/M07H01.tra
#   inflating: /content/data/shemo/transcript/final script/M07H02.tra
#   inflating: /content/data/shemo/transcript/final script/M07N01.tra
#   inflating: /content/data/shemo/transcript/final script/M07N02.tra
#   inflating: /content/data/shemo/transcript/final script/M07N03.tra
#   inflating: /content/data/shemo/transcript/final script/M07N04.tra
#   inflating: /content/data/shemo/transcript/final script/M07N05.tra
#   inflating: /content/data/shemo/transcript/final script/M07N06.tra
#   inflating: /content/data/shemo/transcript/final script/M07N07.tra
#   inflating: /content/data/shemo/transcript/final script/M07N08.tra
#   inflating: /content/data/shemo/transcript/final script/M07S01.tra
#   inflating: /content/data/shemo/transcript/final script/M07W01.tra
#   inflating: /content/data/shemo/transcript/final script/M08H01.tra
#   inflating: /content/data/shemo/transcript/final script/M08H02.tra
#   inflating: /content/data/shemo/transcript/final script/M08H03.tra
#   inflating: /content/data/shemo/transcript/final script/M08H04.tra
#   inflating: /content/data/shemo/transcript/final script/M08N01.tra
#   inflating: /content/data/shemo/transcript/final script/M08N02.tra
#   inflating: /content/data/shemo/transcript/final script/M08N03.tra
#   inflating: /content/data/shemo/transcript/final script/M08N04.tra
#   inflating: /content/data/shemo/transcript/final script/M08N05.tra
#   inflating: /content/data/shemo/transcript/final script/M08N06.tra
#   inflating: /content/data/shemo/transcript/final script/M08N07.tra
#   inflating: /content/data/shemo/transcript/final script/M08N08.tra
#   inflating: /content/data/shemo/transcript/final script/M08N09.tra
#   inflating: /content/data/shemo/transcript/final script/M08N10.tra
#   inflating: /content/data/shemo/transcript/final script/M08N11.tra
#   inflating: /content/data/shemo/transcript/final script/M08S01.tra
#   inflating: /content/data/shemo/transcript/final script/M09A01.tra
#   inflating: /content/data/shemo/transcript/final script/M09A02.tra
#   inflating: /content/data/shemo/transcript/final script/M09A03.tra
#   inflating: /content/data/shemo/transcript/final script/M09A04.tra
#   inflating: /content/data/shemo/transcript/final script/M09A05.tra
#   inflating: /content/data/shemo/transcript/final script/M09A06.tra
#   inflating: /content/data/shemo/transcript/final script/M09A07.tra
#   inflating: /content/data/shemo/transcript/final script/M09A08.tra
#   inflating: /content/data/shemo/transcript/final script/M09A09.tra
#   inflating: /content/data/shemo/transcript/final script/M09A10.tra
#   inflating: /content/data/shemo/transcript/final script/M09A11.tra
#   inflating: /content/data/shemo/transcript/final script/M09A12.tra
#   inflating: /content/data/shemo/transcript/final script/M09A13.tra
#   inflating: /content/data/shemo/transcript/final script/M09A14.tra
#   inflating: /content/data/shemo/transcript/final script/M09A15.tra
#   inflating: /content/data/shemo/transcript/final script/M09A16.tra
#   inflating: /content/data/shemo/transcript/final script/M09A17.tra
#   inflating: /content/data/shemo/transcript/final script/M09A18.tra
#   inflating: /content/data/shemo/transcript/final script/M09A19.tra
#   inflating: /content/data/shemo/transcript/final script/M09A20.tra
#   inflating: /content/data/shemo/transcript/final script/M09A21.tra
#   inflating: /content/data/shemo/transcript/final script/M09A22.tra
#   inflating: /content/data/shemo/transcript/final script/M09A23.tra
#   inflating: /content/data/shemo/transcript/final script/M09N01.tra
#   inflating: /content/data/shemo/transcript/final script/M09N02.tra
#   inflating: /content/data/shemo/transcript/final script/M09N03.tra
#   inflating: /content/data/shemo/transcript/final script/M10A01.tra
#   inflating: /content/data/shemo/transcript/final script/M10A02.tra
#   inflating: /content/data/shemo/transcript/final script/M10F01.tra
#   inflating: /content/data/shemo/transcript/final script/M10N01.tra
#   inflating: /content/data/shemo/transcript/final script/M11H01.tra
#   inflating: /content/data/shemo/transcript/final script/M11H02.tra
#   inflating: /content/data/shemo/transcript/final script/M11H03.tra
#   inflating: /content/data/shemo/transcript/final script/M11H04.tra
#   inflating: /content/data/shemo/transcript/final script/M11H05.tra
#   inflating: /content/data/shemo/transcript/final script/M11H06.tra
#   inflating: /content/data/shemo/transcript/final script/M11H07.tra
#   inflating: /content/data/shemo/transcript/final script/M11H08.tra
#   inflating: /content/data/shemo/transcript/final script/M11H09.tra
#   inflating: /content/data/shemo/transcript/final script/M11N01.tra
#   inflating: /content/data/shemo/transcript/final script/M11N02.tra
#   inflating: /content/data/shemo/transcript/final script/M11N03.tra
#   inflating: /content/data/shemo/transcript/final script/M11N04.tra
#   inflating: /content/data/shemo/transcript/final script/M11N05.tra
#   inflating: /content/data/shemo/transcript/final script/M11N06.tra
#   inflating: /content/data/shemo/transcript/final script/M11S01.tra
#   inflating: /content/data/shemo/transcript/final script/M12A01.tra
#   inflating: /content/data/shemo/transcript/final script/M12A02.tra
#   inflating: /content/data/shemo/transcript/final script/M12A03.tra
#   inflating: /content/data/shemo/transcript/final script/M12A04.tra
#   inflating: /content/data/shemo/transcript/final script/M12A05.tra
#   inflating: /content/data/shemo/transcript/final script/M12A06.tra
#   inflating: /content/data/shemo/transcript/final script/M12A07.tra
#   inflating: /content/data/shemo/transcript/final script/M12A08.tra
#   inflating: /content/data/shemo/transcript/final script/M12A09.tra
#   inflating: /content/data/shemo/transcript/final script/M12A10.tra
#   inflating: /content/data/shemo/transcript/final script/M12A11.tra
#   inflating: /content/data/shemo/transcript/final script/M12A12.tra
#   inflating: /content/data/shemo/transcript/final script/M12A13.tra
#   inflating: /content/data/shemo/transcript/final script/M12A14.tra
#   inflating: /content/data/shemo/transcript/final script/M12A15.tra
#   inflating: /content/data/shemo/transcript/final script/M12A16.tra
#   inflating: /content/data/shemo/transcript/final script/M12A17.tra
#   inflating: /content/data/shemo/transcript/final script/M12A18.tra
#   inflating: /content/data/shemo/transcript/final script/M12A19.tra
#   inflating: /content/data/shemo/transcript/final script/M12A20.tra
# ...
#   inflating: /content/data/shemo/transcript/final text/M44N25.ort
#   inflating: /content/data/shemo/transcript/final text/M44N26.ort
#   inflating: /content/data/shemo/transcript/final text/M44S01.ort
#   inflating: /content/data/shemo/transcript/final text/M44S02.ort
#   inflating: /content/data/shemo/transcript/final text/M44S03.ort
#   inflating: /content/data/shemo/transcript/final text/M44S04.ort
#   inflating: /content/data/shemo/transcript/final text/M44W01.ort
#   inflating: /content/data/shemo/transcript/final text/M44W02.ort
#   inflating: /content/data/shemo/transcript/final text/M44W03.ort
#   inflating: /content/data/shemo/transcript/final text/M45N01.ort
#   inflating: /content/data/shemo/transcript/final text/M45N02.ort
#   inflating: /content/data/shemo/transcript/final text/M45N03.ort
#   inflating: /content/data/shemo/transcript/final text/M45N04.ort
#   inflating: /content/data/shemo/transcript/final text/M45N05.ort
#   inflating: /content/data/shemo/transcript/final text/M45N06.ort
#   inflating: /content/data/shemo/transcript/final text/M45W01.ort
#   inflating: /content/data/shemo/transcript/final text/M46A01.ort
#   inflating: /content/data/shemo/transcript/final text/M46A02.ort
#   inflating: /content/data/shemo/transcript/final text/M46A03.ort
#   inflating: /content/data/shemo/transcript/final text/M46A04.ort
#   inflating: /content/data/shemo/transcript/final text/M46A05.ort
#   inflating: /content/data/shemo/transcript/final text/M46N01.ort
#   inflating: /content/data/shemo/transcript/final text/M46N02.ort
#   inflating: /content/data/shemo/transcript/final text/M46N03.ort
#   inflating: /content/data/shemo/transcript/final text/M46N04.ort
#   inflating: /content/data/shemo/transcript/final text/M46N05.ort
#   inflating: /content/data/shemo/transcript/final text/M46N06.ort
#   inflating: /content/data/shemo/transcript/final text/M46N07.ort
#   inflating: /content/data/shemo/transcript/final text/M46N08.ort
#   inflating: /content/data/shemo/transcript/final text/M46N09.ort
#   inflating: /content/data/shemo/transcript/final text/M46N10.ort
#   inflating: /content/data/shemo/transcript/final text/M46N11.ort
#   inflating: /content/data/shemo/transcript/final text/M46W01.ort
#   inflating: /content/data/shemo/transcript/final text/M47A01.ort
#   inflating: /content/data/shemo/transcript/final text/M47A02.ort
#   inflating: /content/data/shemo/transcript/final text/M47A03.ort
#   inflating: /content/data/shemo/transcript/final text/M47A04.ort
#   inflating: /content/data/shemo/transcript/final text/M47A05.ort
#   inflating: /content/data/shemo/transcript/final text/M47A06.ort
#   inflating: /content/data/shemo/transcript/final text/M47A07.ort
#   inflating: /content/data/shemo/transcript/final text/M47A08.ort
#   inflating: /content/data/shemo/transcript/final text/M47A09.ort
#   inflating: /content/data/shemo/transcript/final text/M47A10.ort
#   inflating: /content/data/shemo/transcript/final text/M47A11.ort
#   inflating: /content/data/shemo/transcript/final text/M47A12.ort
#   inflating: /content/data/shemo/transcript/final text/M47A13.ort
#   inflating: /content/data/shemo/transcript/final text/M47A14.ort
#   inflating: /content/data/shemo/transcript/final text/M47A15.ort
#   inflating: /content/data/shemo/transcript/final text/M47A16.ort
#   inflating: /content/data/shemo/transcript/final text/M47A17.ort
#   inflating: /content/data/shemo/transcript/final text/M47A18.ort
#   inflating: /content/data/shemo/transcript/final text/M47A19.ort
#   inflating: /content/data/shemo/transcript/final text/M47A20.ort
#   inflating: /content/data/shemo/transcript/final text/M47H01.ort
#   inflating: /content/data/shemo/transcript/final text/M47N01.ort
#   inflating: /content/data/shemo/transcript/final text/M47N02.ort
#   inflating: /content/data/shemo/transcript/final text/M47N03.ort
#   inflating: /content/data/shemo/transcript/final text/M47N04.ort
#   inflating: /content/data/shemo/transcript/final text/M47N05.ort
#   inflating: /content/data/shemo/transcript/final text/M47N06.ort
#   inflating: /content/data/shemo/transcript/final text/M47N07.ort
#   inflating: /content/data/shemo/transcript/final text/M47N08.ort
#   inflating: /content/data/shemo/transcript/final text/M47N09.ort
#   inflating: /content/data/shemo/transcript/final text/M47N10.ort
#   inflating: /content/data/shemo/transcript/final text/M47N11.ort
#   inflating: /content/data/shemo/transcript/final text/M47N12.ort
#   inflating: /content/data/shemo/transcript/final text/M47N13.ort
#   inflating: /content/data/shemo/transcript/final text/M47N14.ort
#   inflating: /content/data/shemo/transcript/final text/M47N15.ort
#   inflating: /content/data/shemo/transcript/final text/M47N16.ort
#   inflating: /content/data/shemo/transcript/final text/M47N17.ort
#   inflating: /content/data/shemo/transcript/final text/M47N18.ort
#   inflating: /content/data/shemo/transcript/final text/M47N19.ort
#   inflating: /content/data/shemo/transcript/final text/M47N20.ort
#   inflating: /content/data/shemo/transcript/final text/M47N21.ort
#   inflating: /content/data/shemo/transcript/final text/M47N22.ort
#   inflating: /content/data/shemo/transcript/final text/M47N23.ort
#   inflating: /content/data/shemo/transcript/final text/M47N24.ort
#   inflating: /content/data/shemo/transcript/final text/M47N25.ort
#   inflating: /content/data/shemo/transcript/final text/M47N26.ort
#   inflating: /content/data/shemo/transcript/final text/M47N27.ort
#   inflating: /content/data/shemo/transcript/final text/M47W01.ort
#   inflating: /content/data/shemo/transcript/final text/M47W02.ort
#   inflating: /content/data/shemo/transcript/final text/M48A01.ort
#   inflating: /content/data/shemo/transcript/final text/M48A02.ort
#   inflating: /content/data/shemo/transcript/final text/M48A03.ort
#   inflating: /content/data/shemo/transcript/final text/M48A04.ort
#   inflating: /content/data/shemo/transcript/final text/M48N01.ort
#   inflating: /content/data/shemo/transcript/final text/M48N02.ort
#   inflating: /content/data/shemo/transcript/final text/M48N03.ort
#   inflating: /content/data/shemo/transcript/final text/M48N04.ort
#   inflating: /content/data/shemo/transcript/final text/M48N05.ort
#   inflating: /content/data/shemo/transcript/final text/M48N06.ort
#   inflating: /content/data/shemo/transcript/final text/M48N07.ort
#   inflating: /content/data/shemo/transcript/final text/M48N08.ort
#   inflating: /content/data/shemo/transcript/final text/M48N09.ort
#   inflating: /content/data/shemo/transcript/final text/M48N10.ort
#   inflating: /content/data/shemo/transcript/final text/M48N11.ort
#   inflating: /content/data/shemo/transcript/final text/M48N12.ort
#   inflating: /content/data/shemo/transcript/final text/M48S01.ort
#   inflating: /content/data/shemo/transcript/final text/M48W01.ort
#   inflating: /content/data/shemo/transcript/final text/M49H01.ort
#   inflating: /content/data/shemo/transcript/final text/M49N01.ort
#   inflating: /content/data/shemo/transcript/final text/M49N02.ort
#   inflating: /content/data/shemo/transcript/final text/M49N03.ort
#   inflating: /content/data/shemo/transcript/final text/M49N04.ort
#   inflating: /content/data/shemo/transcript/final text/M49N05.ort
#   inflating: /content/data/shemo/transcript/final text/M50A01.ort
#   inflating: /content/data/shemo/transcript/final text/M50A02.ort
#   inflating: /content/data/shemo/transcript/final text/M50A03.ort
#   inflating: /content/data/shemo/transcript/final text/M50A04.ort
#   inflating: /content/data/shemo/transcript/final text/M50A05.ort
#   inflating: /content/data/shemo/transcript/final text/M50A06.ort
#   inflating: /content/data/shemo/transcript/final text/M50A07.ort
#   inflating: /content/data/shemo/transcript/final text/M50A08.ort
#   inflating: /content/data/shemo/transcript/final text/M50A09.ort
#   inflating: /content/data/shemo/transcript/final text/M50A10.ort
#   inflating: /content/data/shemo/transcript/final text/M50A11.ort
#   inflating: /content/data/shemo/transcript/final text/M50A12.ort
#   inflating: /content/data/shemo/transcript/final text/M50N01.ort
#   inflating: /content/data/shemo/transcript/final text/M50N02.ort
#   inflating: /content/data/shemo/transcript/final text/M50N03.ort
#   inflating: /content/data/shemo/transcript/final text/M51N01.ort
#   inflating: /content/data/shemo/transcript/final text/M51N02.ort
#   inflating: /content/data/shemo/transcript/final text/M51N03.ort
#   inflating: /content/data/shemo/transcript/final text/M51N04.ort
#   inflating: /content/data/shemo/transcript/final text/M51N05.ort
#   inflating: /content/data/shemo/transcript/final text/M51N06.ort
#   inflating: /content/data/shemo/transcript/final text/M51N07.ort
#   inflating: /content/data/shemo/transcript/final text/M51N08.ort
#   inflating: /content/data/shemo/transcript/final text/M51N09.ort
#   inflating: /content/data/shemo/transcript/final text/M51N10.ort
#   inflating: /content/data/shemo/transcript/final text/M51N11.ort
#   inflating: /content/data/shemo/transcript/final text/M51N12.ort
#   inflating: /content/data/shemo/transcript/final text/M51N13.ort
#   inflating: /content/data/shemo/transcript/final text/M51N14.ort
#   inflating: /content/data/shemo/transcript/final text/M51N15.ort
#   inflating: /content/data/shemo/transcript/final text/M51N16.ort
#   inflating: /content/data/shemo/transcript/final text/M51N17.ort
#   inflating: /content/data/shemo/transcript/final text/M51N18.ort
#   inflating: /content/data/shemo/transcript/final text/M51N19.ort
#   inflating: /content/data/shemo/transcript/final text/M51N20.ort
#   inflating: /content/data/shemo/transcript/final text/M51N21.ort
#   inflating: /content/data/shemo/transcript/final text/M51N22.ort
#   inflating: /content/data/shemo/transcript/final text/M51N23.ort
#   inflating: /content/data/shemo/transcript/final text/M51N24.ort
#   inflating: /content/data/shemo/transcript/final text/M51S01.ort
#   inflating: /content/data/shemo/transcript/final text/M51S02.ort
#   inflating: /content/data/shemo/transcript/final text/M52N01.ort
#   inflating: /content/data/shemo/transcript/final text/M52N02.ort
#   inflating: /content/data/shemo/transcript/final text/M52N03.ort
#   inflating: /content/data/shemo/transcript/final text/M52S01.ort
#   inflating: /content/data/shemo/transcript/final text/M52S02.ort
#   inflating: /content/data/shemo/transcript/final text/M52S03.ort
#   inflating: /content/data/shemo/transcript/final text/M52S04.ort
#   inflating: /content/data/shemo/transcript/final text/M53A01.ort
#   inflating: /content/data/shemo/transcript/final text/M53A02.ort
#   inflating: /content/data/shemo/transcript/final text/M53A03.ort
#   inflating: /content/data/shemo/transcript/final text/M53A04.ort
#   inflating: /content/data/shemo/transcript/final text/M53A05.ort
#   inflating: /content/data/shemo/transcript/final text/M53A06.ort
#   inflating: /content/data/shemo/transcript/final text/M53A07.ort
#   inflating: /content/data/shemo/transcript/final text/M53A08.ort
#   inflating: /content/data/shemo/transcript/final text/M53A09.ort
#   inflating: /content/data/shemo/transcript/final text/M53A10.ort
#   inflating: /content/data/shemo/transcript/final text/M53A11.ort
#   inflating: /content/data/shemo/transcript/final text/M53A12.ort
#   inflating: /content/data/shemo/transcript/final text/M53A13.ort
#   inflating: /content/data/shemo/transcript/final text/M53A14.ort
#   inflating: /content/data/shemo/transcript/final text/M53A15.ort
#   inflating: /content/data/shemo/transcript/final text/M53A16.ort
#   inflating: /content/data/shemo/transcript/final text/M53A17.ort
#   inflating: /content/data/shemo/transcript/final text/M53A18.ort
#   inflating: /content/data/shemo/transcript/final text/M53A19.ort
#   inflating: /content/data/shemo/transcript/final text/M53A20.ort
#   inflating: /content/data/shemo/transcript/final text/M53A21.ort
#   inflating: /content/data/shemo/transcript/final text/M53A22.ort
#   inflating: /content/data/shemo/transcript/final text/M53A23.ort
#   inflating: /content/data/shemo/transcript/final text/M53A24.ort
#   inflating: /content/data/shemo/transcript/final text/M53A25.ort
#   inflating: /content/data/shemo/transcript/final text/M53A26.ort
#   inflating: /content/data/shemo/transcript/final text/M53A27.ort
#   inflating: /content/data/shemo/transcript/final text/M53A28.ort
#   inflating: /content/data/shemo/transcript/final text/M53N01.ort
#   inflating: /content/data/shemo/transcript/final text/M53N02.ort
#   inflating: /content/data/shemo/transcript/final text/M53N03.ort
#   inflating: /content/data/shemo/transcript/final text/M53N04.ort
#   inflating: /content/data/shemo/transcript/final text/M53N05.ort
#   inflating: /content/data/shemo/transcript/final text/M53N06.ort
#   inflating: /content/data/shemo/transcript/final text/M53N07.ort
#   inflating: /content/data/shemo/transcript/final text/M53N08.ort
#   inflating: /content/data/shemo/transcript/final text/M53N09.ort
#   inflating: /content/data/shemo/transcript/final text/M53N10.ort
#   inflating: /content/data/shemo/transcript/final text/M53N11.ort
#   inflating: /content/data/shemo/transcript/final text/M53N12.ort
#   inflating: /content/data/shemo/transcript/final text/M53N13.ort
#   inflating: /content/data/shemo/transcript/final text/M53N14.ort
#   inflating: /content/data/shemo/transcript/final text/M53N15.ort
#   inflating: /content/data/shemo/transcript/final text/M53N16.ort
#   inflating: /content/data/shemo/transcript/final text/M53N17.ort
#   inflating: /content/data/shemo/transcript/final text/M53N18.ort
#   inflating: /content/data/shemo/transcript/final text/M53N19.ort
#   inflating: /content/data/shemo/transcript/final text/M53N20.ort
#   inflating: /content/data/shemo/transcript/final text/M53N21.ort
#   inflating: /content/data/shemo/transcript/final text/M53N22.ort
#   inflating: /content/data/shemo/transcript/final text/M53N23.ort
#   inflating: /content/data/shemo/transcript/final text/M53N24.ort
#   inflating: /content/data/shemo/transcript/final text/M53N25.ort
#   inflating: /content/data/shemo/transcript/final text/M53N26.ort
#   inflating: /content/data/shemo/transcript/final text/M53N27.ort
#   inflating: /content/data/shemo/transcript/final text/M53S01.ort
#   inflating: /content/data/shemo/transcript/final text/M53S02.ort
#   inflating: /content/data/shemo/transcript/final text/M54A01.ort
#   inflating: /content/data/shemo/transcript/final text/M54N02.ort
#   inflating: /content/data/shemo/transcript/final text/M54N03.ort
#   inflating: /content/data/shemo/transcript/final text/M54N04.ort
#   inflating: /content/data/shemo/transcript/final text/M54S01.ort
#   inflating: /content/data/shemo/transcript/final text/M55A01.ort
#   inflating: /content/data/shemo/transcript/final text/M55A02.ort
#   inflating: /content/data/shemo/transcript/final text/M55A03.ort
#   inflating: /content/data/shemo/transcript/final text/M55A04.ort
#   inflating: /content/data/shemo/transcript/final text/M55H01.ort
#   inflating: /content/data/shemo/transcript/final text/M55N01.ort
#   inflating: /content/data/shemo/transcript/final text/M55N02.ort
#   inflating: /content/data/shemo/transcript/final text/M55N03.ort
#   inflating: /content/data/shemo/transcript/final text/M55N04.ort
#   inflating: /content/data/shemo/transcript/final text/M55N05.ort
#   inflating: /content/data/shemo/transcript/final text/M55N06.ort
#   inflating: /content/data/shemo/transcript/final text/M56A01.ort
#   inflating: /content/data/shemo/transcript/final text/M56N01.ort
#   inflating: /content/data/shemo/transcript/final text/M56N02.ort
#   inflating: /content/data/shemo/transcript/final text/M56N03.ort
#   inflating: /content/data/shemo/transcript/final text/M56N04.ort
#   inflating: /content/data/shemo/transcript/final text/M56N05.ort
#   inflating: /content/data/shemo/transcript/final text/M56W01.ort

# %%
abs_path_to_data = os.path.join("/content", "data", "shemo")
# !ls {abs_path_to_data}
# Out:
# female	male  transcript

# %%
data = []
for txtfile in tqdm(glob.glob(f"{abs_path_to_data}/transcript/final text/*.ort")):
    with open(txtfile, "r", encoding="utf-8") as f:
        text = f.read()
        _id = txtfile.split("/")[-1].split(".")[0]
        male_path = f"{abs_path_to_data}/male/{_id}.wav"
        female_path = f"{abs_path_to_data}/female/{_id}.wav"
        
        if "M" in _id and os.path.exists(male_path):
            data.append({
                "_id": _id,
                "sentence": text,
                "path": male_path.strip(),
                "gender": "M"
            })
        
        if "F" in _id and os.path.exists(female_path):
            data.append({
                "_id": _id,
                "sentence": text,
                "path": female_path.strip(),
                "gender": "F"
            })
        
#     break
    
df = pd.DataFrame(data)
df.head()
# Out:
# 100%|██████████| 3000/3000 [00:00<00:00, 31671.46it/s]
#       _id                                           sentence  \
# 0  M22S02             من که دیگه هیچی از گلوم پایین نمی‎ره\n
# 1  F07S36         خواهش می‎کنم دیگه راجع به اون صحبت نکنین\n
# 2  M12N81                      دلاله ممکنه هر لحظه سر برسه\n
# 3  M31N01                         برای اینکه به شما مدیونم\n
# 4  M05N13  توی این زمان دکتر بهشتی درس خارج فقه و اصول رو...
#
#                                     path gender
# 0    /content/data/shemo/male/M22S02.wav      M
# 1  /content/data/shemo/female/F07S36.wav      F
# 2    /content/data/shemo/male/M12N81.wav      M
# 3    /content/data/shemo/male/M31N01.wav      M
# 4    /content/data/shemo/male/M05N13.wav      M

# %%
print(f"Step 0: {len(df)}")

df["status"] = df["path"].apply(lambda path: True if os.path.exists(path) else None)
df = df.dropna(subset=["path"])
df = df.drop("status", 1)
print(f"Step 1: {len(df)}")

# df["prev_sentence"] = df["sentence"]
df["sentence"] = df["sentence"].apply(lambda t: normalizer(t))
df = df.dropna(subset=["sentence"])
print(f"Step 2: {len(df)}")

# df = df[["prev_sentence", "sentence", "path"]]
# df = df[["sentence", "path"]]
df = df.sample(frac=1)
df = df.reset_index(drop=True)
df.head()
# Out:
# Step 0: 2838
# Step 1: 2838
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """
# Step 2: 2838
#       _id                                           sentence  \
# 0  F21A10  تو نمی تونی اونو بگیری تو تا همین چند لحظه منک...
# 1  M29A03                  لابد اومدید به سن زیاد من بخندید
# 2  F07H02                                   آه مچکرم اورلیا
# 3  F19N23  پروین که در مکتب پدر و مادر ادیب و خردمندش بسی...
# 4  M40N18       اون مردو نجات داد و بادبان کشتی رو مرمت کرد
#
#                                     path gender
# 0  /content/data/shemo/female/F21A10.wav      F
# 1    /content/data/shemo/male/M29A03.wav      M
# 2  /content/data/shemo/female/F07H02.wav      F
# 3  /content/data/shemo/female/F19N23.wav      F
# 4    /content/data/shemo/male/M40N18.wav      M

# %%
main_vocab = ["ح", "چ", "ج", "ث", "ت", "پ", "ب", "آ", "ا", "ش", "س", "ژ", "ز", "ر", "ذ", "د", "خ", "ق", "ف", "غ", "ع", "ظ", "ط", "ض", "ص", "ی", "ه", "و", "ن", "م", "ل", "گ", "ک"]
text = " ".join(df["sentence"].values.tolist())
vocab = list(sorted(set(text)))

for v in main_vocab:
    if v not in vocab:
        print("v", v)

print(len(main_vocab), len(vocab))
print(vocab)
# Out:
# 33 36
# [' ', 'ء', 'آ', 'ئ', 'ا', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ل', 'م', 'ن', 'ه', 'و', 'پ', 'چ', 'ژ', 'ک', 'گ', 'ی']

# %%
import torchaudio
import librosa
import IPython.display as ipd
import numpy as np

idx = np.random.randint(0, len(df))
print(idx)
sample = df.iloc[idx]

path = sample["path"]
print(sample["sentence"], "\n")
speech, sr = torchaudio.load(path)
speech = speech[0].numpy().squeeze()

speech = librosa.resample(np.asarray(speech), sr, 16_000)
ipd.Audio(data=np.asarray(speech), autoplay=True, rate=16000)
# Out:
# 1061
# چرا چرا بازی می کنه
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
train_df, test_df = train_test_split(df, test_size=0.1, random_state=101, stratify=df["gender"])

train_df = train_df[["path", "sentence"]]
train_df = train_df.reset_index(drop=True)

test_df = test_df[["path", "sentence"]]
test_df = test_df.reset_index(drop=True)

print(train_df.shape)
print(test_df.shape)
# Out:
# (2554, 2)
# (284, 2)

# %%
save_path = "/".join(abs_path_to_data.split('/'))
print(save_path)

train_df.to_csv(f"{save_path}/train.csv", sep="\t", encoding="utf-8", index=False)
test_df.to_csv(f"{save_path}/test.csv", sep="\t", encoding="utf-8", index=False)

print(train_df.shape)
print(test_df.shape)
# Out:
# /content/data/shemo
# (2554, 2)
# (284, 2)

# %%
common_voice_train = load_dataset("csv", data_files={"train": "/content/data/shemo/train.csv"}, delimiter="\t")["train"]
common_voice_test = load_dataset("csv", data_files={"test": "/content/data/shemo/test.csv"}, delimiter="\t")["test"]

print(common_voice_train)
print(common_voice_test)
# Out:
# Using custom data configuration default-306f85314c29d303
# Downloading and preparing dataset csv/default to /content/cache/csv/default-306f85314c29d303/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /content/cache/csv/default-306f85314c29d303/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Using custom data configuration default-11c85cda03fa3ff8
# Downloading and preparing dataset csv/default to /content/cache/csv/default-11c85cda03fa3ff8/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /content/cache/csv/default-11c85cda03fa3ff8/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['path', 'sentence'],
#     num_rows: 2554
# })
# Dataset({
#     features: ['path', 'sentence'],
#     num_rows: 284
# })

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(common_voice_train.remove_columns(["path"]), num_examples=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>این همون مجله ای نیست که روزی سی بار از اول تا آخرشو می جویدی</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>هر آدمی که ادعای آدمیت می کنه ضامن بدبختی و خوشبختی هم نوعشه</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>وقتی نور از مثلا اون صحنه به درون عدسی و بعد به داخل جعبه می تابه اون صحنه رو بازتاب می ده جوری که ما می تونیم تصویر اون رو ببینیم</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>تو باید برای اون تصمیم بگیری</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>نگفتم</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>من با فرانس کار داشتم</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>کیه که بتونه یه سال تموم گوشه خونه بشینه و درس بخونه</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>حرفای من بیهوده است</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>به نظر خودت گنگسترا از کجا متوجه شدن که تو به رازشون پی بردی</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>اتومبیل را به دقت معاینه کردم با اینکه شسته بودنش ولی روی صندلی عقبش هنوز لکه هایی دیده می شد که احتمال داشت لکه خون باشه</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>خداییش ارث پدر نرگسه و باید داد دست خودش بره پی کارش</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>نه</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>تمام دیشبو منتظرت بودم</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>تو یکی از بهترین سرداران خاقانی کسی که سالها به اون خدمت کرده حالا چطور راضی می شی به این راحتی کنار بکشی تا یک اجنبی جای تو رو بگیره</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>الیزابت بعد از سردرگمی های بسیار در میون آرزوهای مختلف سرانجام نوزاد رو در آغوش می گیره و در گوش چپ اون اینطور زمزمه می کنه</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>مغز اقتصادی دسته شولتس</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>زبان عبری به چه دردش می خورد</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>متوجه نیستش که همون موقع که یک دستش رو در دست تو می گذاره دست دیگرش در دست عزرائیله</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>پس درسته که خودکشی کرده تو همون خونه واریکینو</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>فکر کنم خودشه</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# normalize the text to only have lower case letters and append a word separator token at the end.

# %%
def normalizer(batch, chars_to_ignore=chars_to_ignore, chars_to_mapping=chars_to_mapping):
    chars_to_ignore_regex = f"""[{"".join(chars_to_ignore)}]"""
    text = batch["sentence"].lower().strip()

    text = _normalizer.normalize(text)
    text = multiple_replace(text, chars_to_mapping)
    text = remove_special_characters(text, chars_to_ignore_regex)
    text = re.sub(" +", " ", text)
    _text = []
    for word in text.split():
        try:
            word = int(word)
            _text.append(words(word))
        except:
            _text.append(word)
            
    text = " ".join(_text) + " "
    text = text.strip()

    if not len(text) > 0:
        return None
    
    batch["sentence"] = text
    
    return batch

# %%
print(common_voice_train[0]["sentence"])
print(common_voice_test[0]["sentence"])
# Out:
# من الان در تنهایی کاملا خوشبختم
# ای خانوم ما هم سرگذشتی داشتیم قسمت ما این بود چه می شه کرد خدا این طور می خواست که من تو زندگی حتی یه روز دلخوشی نداشته باشم یه آب راحت از گلوم پایین نره

# %%
common_voice_train = common_voice_train.map(normalizer, fn_kwargs={"chars_to_ignore": chars_to_ignore, "chars_to_mapping": chars_to_mapping})
common_voice_test = common_voice_test.map(normalizer, fn_kwargs={"chars_to_ignore": chars_to_ignore, "chars_to_mapping": chars_to_mapping})
# Out:
# Parameter 'function'=<function normalizer at 0x7f141b692440> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/2554 [00:00<?, ?ex/s]
#   0%|          | 0/284 [00:00<?, ?ex/s]

# %%
print(common_voice_train[0]["sentence"])
print(common_voice_test[0]["sentence"])
# Out:
# من الان در تنهایی کاملا خوشبختم
# ای خانوم ما هم سرگذشتی داشتیم قسمت ما این بود چه می شه کرد خدا این طور می خواست که من تو زندگی حتی یه روز دلخوشی نداشته باشم یه آب راحت از گلوم پایین نره

# %% [markdown]
# write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch["sentence"])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocab_train = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_train.column_names)
vocab_test = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_test.column_names)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(sorted(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0])))
vocab_list = [vocab for vocab in vocab_list if vocab not in [" ", "\u0307"]]
print(len(vocab_list))
print(vocab_list)
# Out:
# 35
# ['ء', 'آ', 'ئ', 'ا', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ل', 'م', 'ن', 'ه', 'و', 'پ', 'چ', 'ژ', 'ک', 'گ', 'ی']

# %%
vocab_list = list(sorted(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0])))
vocab_list = [vocab for vocab in vocab_list if vocab not in [" ", "\u0307"]]
print(len(vocab_list))
print(vocab_list)
# Out:
# 35
# ['ء', 'آ', 'ئ', 'ا', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ل', 'م', 'ن', 'ه', 'و', 'پ', 'چ', 'ژ', 'ک', 'گ', 'ی']

# %%
special_vocab = ["<pad>", "<s>", "</s>", "<unk>", "|"]

# %%
vocab_dict = {v: k for k, v in enumerate(special_vocab + vocab_list)}
print(len(vocab_dict))
print(vocab_dict)
# Out:
# 40
# {'<pad>': 0, '<s>': 1, '</s>': 2, '<unk>': 3, '|': 4, 'ء': 5, 'آ': 6, 'ئ': 7, 'ا': 8, 'ب': 9, 'ت': 10, 'ث': 11, 'ج': 12, 'ح': 13, 'خ': 14, 'د': 15, 'ذ': 16, 'ر': 17, 'ز': 18, 'س': 19, 'ش': 20, 'ص': 21, 'ض': 22, 'ط': 23, 'ظ': 24, 'ع': 25, 'غ': 26, 'ف': 27, 'ق': 28, 'ل': 29, 'م': 30, 'ن': 31, 'ه': 32, 'و': 33, 'پ': 34, 'چ': 35, 'ژ': 36, 'ک': 37, 'گ': 38, 'ی': 39}

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %%
save_dir = "/content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo"
model_name_or_path = "m3hrdadfi/wav2vec2-large-xlsr-persian-v2"

# %%
from transformers.trainer_utils import get_last_checkpoint

last_checkpoint = None
if os.path.exists(save_dir):
    last_checkpoint = get_last_checkpoint(save_dir)

print(last_checkpoint if last_checkpoint else str(None))
# Out:
# /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/checkpoint-500

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

if not os.path.exists(save_dir) and not model_name_or_path:
    print("Load from scratch")
    tokenizer = Wav2Vec2CTCTokenizer(
        "./fa.vocab.json", 
        bos_token="<s>",
        eos_token="</s>",
        unk_token="<unk>",
        pad_token="<pad>",
        word_delimiter_token="|",
        do_lower_case=False
    )
else:
    print(f"Load from {model_name_or_path}")
    tokenizer = Wav2Vec2CTCTokenizer.from_pretrained(model_name_or_path)
# Out:
# Load from m3hrdadfi/wav2vec2-large-xlsr-persian-v2
# Downloading:   0%|          | 0.00/398 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "

# %%
text = "از مهمونداری کنار بکشم"
print(" ".join(tokenizer.tokenize(text)))
print(tokenizer.decode(tokenizer.encode(text)))
# Out:
# ا ز | م ه م و ن د ا ر ی | ک ن ا ر | ب ک ش م
# از مهمونداری کنار بکشم

# %% [markdown]
# create the feature extractor.

# %%
from transformers import Wav2Vec2FeatureExtractor

if not os.path.exists(save_dir) and not model_name_or_path:
    print("Load from scratch")
    feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)
else:
    print(f"Load from {model_name_or_path}")
    feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(model_name_or_path)
# Out:
# Load from m3hrdadfi/wav2vec2-large-xlsr-persian-v2
# Downloading:   0%|          | 0.00/158 [00:00<?, ?B/s]

# %%
from transformers import Wav2Vec2Processor

if not os.path.exists(save_dir) and not model_name_or_path:
    print("Load from scratch")
    processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)
else:
    print(f"Load from {model_name_or_path}")
    processor = Wav2Vec2Processor.from_pretrained(model_name_or_path)
# Out:
# Load from m3hrdadfi/wav2vec2-large-xlsr-persian-v2
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "

# %%
if len(processor.tokenizer.get_vocab()) == len(processor.tokenizer):
    print(len(processor.tokenizer))
# Out:
# 40

# %%
if not os.path.exists(save_dir):
    print("Saving ...")
    processor.save_pretrained(save_dir)
    print("Saved!")

# %% [markdown]
# prepare the datase

# %%
common_voice_train[0]
# Out:
# {'path': '/content/data/shemo/male/M25H01.wav',
#  'sentence': 'من الان در تنهایی کاملا خوشبختم'}

# %%
import torchaudio
import librosa


target_sampling_rate = 16_000

def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    speech_array = speech_array.squeeze().numpy()
    speech_array = librosa.resample(np.asarray(speech_array), sampling_rate, target_sampling_rate)
    
    
    batch["speech"] = speech_array
    batch["sampling_rate"] = target_sampling_rate
    batch["duration_in_seconds"] = len(batch["speech"]) / target_sampling_rate
    batch["target_text"] = batch["sentence"]
    return batch

# %%
common_voice_train = common_voice_train.map(speech_file_to_array_fn, remove_columns=common_voice_train.column_names, num_proc=4)
common_voice_test = common_voice_test.map(speech_file_to_array_fn, remove_columns=common_voice_test.column_names, num_proc=4)
# Out:
# #0:   0%|          | 0/639 [00:00<?, ?ex/s]
# #1:   0%|          | 0/639 [00:00<?, ?ex/s]
# #2:   0%|          | 0/638 [00:00<?, ?ex/s]
# #3:   0%|          | 0/638 [00:00<?, ?ex/s]
# #0:   0%|          | 0/71 [00:00<?, ?ex/s]
# #1:   0%|          | 0/71 [00:00<?, ?ex/s]
# #2:   0%|          | 0/71 [00:00<?, ?ex/s]
# #3:   0%|          | 0/71 [00:00<?, ?ex/s]

# %%
common_voice_train[0].keys()
# Out:
# dict_keys(['speech', 'sampling_rate', 'duration_in_seconds', 'target_text'])

# %%
print(common_voice_train[0]["sampling_rate"])
print(common_voice_test[0]["sampling_rate"])
# Out:
# 16000
# 16000

# %%
min_duration_in_seconds = 5.0
max_duration_in_seconds = 10.0

def filter_by_max_duration(batch):
    return min_duration_in_seconds <= batch["duration_in_seconds"] <= max_duration_in_seconds

# %%
print(f"Split sizes [BEFORE]: {len(common_voice_train)} train and {len(common_voice_test)} validation.")

_common_voice_train = common_voice_train.filter(filter_by_max_duration, num_proc=4)
_common_voice_test = common_voice_test
# _common_voice_test = common_voice_test.filter(filter_by_max_duration, num_proc=4)

print(f"Split sizes [AFTER]: {len(_common_voice_train)} train and {len(_common_voice_test)} validation.")
# Out:
# Split sizes [BEFORE]: 2554 train and 284 validation.
# #0:   0%|          | 0/1 [00:00<?, ?ba/s]
# #1:   0%|          | 0/1 [00:00<?, ?ba/s]
# #2:   0%|          | 0/1 [00:00<?, ?ba/s]
# #3:   0%|          | 0/1 [00:00<?, ?ba/s]
# Split sizes [AFTER]: 527 train and 284 validation.

# %%
import IPython.display as ipd
import numpy as np
import random

sample = _common_voice_train
rand_int = random.randint(0, len(sample))

print("Target text:", sample[rand_int]["target_text"])
print("Input array shape:", np.asarray(sample[rand_int]["speech"]).shape)
print("Sampling rate:", sample[rand_int]["sampling_rate"])

ipd.Audio(data=np.asarray(sample[rand_int]["speech"]), autoplay=True, rate=16000)
# Out:
# Target text: تازه به جای اینکه خبر مرگ منو درست بنویسی توهین هم می کنی می نویسی اون یکی از هنرمندان عرصه رادیو بود از کارهای او می توان به مجموعه نمایشی چهارفصل و سه نقطه اشاره کرد
# Input array shape: (148593,)
# Sampling rate: 16000
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
import numpy as np
import random

sample = _common_voice_train
rand_int = random.randint(0, len(sample))

print("Target text:", sample[rand_int]["target_text"])
print("Input array shape:", np.asarray(sample[rand_int]["speech"]).shape)
print("Sampling rate:", sample[rand_int]["sampling_rate"])

ipd.Audio(data=np.asarray(sample[rand_int]["speech"]), autoplay=True, rate=16000)
# Out:
# Target text: اشخاصی رو که وقتی در نتیجه اهمال یا اشتباه خودشون گرفتاری هایی براشون پیش می آد می فرستن دنبال سرکدبانوی ما و مزاحم کارای او می شن نمی خوایم
# Input array shape: (148365,)
# Sampling rate: 16000
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
_common_voice_train = _common_voice_train.map(prepare_dataset, remove_columns=_common_voice_train.column_names, batch_size=8, num_proc=4, batched=True)
_common_voice_test = _common_voice_test.map(prepare_dataset, remove_columns=_common_voice_test.column_names, batch_size=8, num_proc=4, batched=True)
# Out:
# #0:   0%|          | 0/17 [00:00<?, ?ba/s]
# #1:   0%|          | 0/17 [00:00<?, ?ba/s]
# #2:   0%|          | 0/17 [00:00<?, ?ba/s]
# #3:   0%|          | 0/17 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# #0:   0%|          | 0/9 [00:00<?, ?ba/s]
# #1:   0%|          | 0/9 [00:00<?, ?ba/s]
# #2:   0%|          | 0/9 [00:00<?, ?ba/s]
# #3:   0%|          | 0/9 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")

# %%
import random


def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)
    
    if isinstance(label_str, list):
        if isinstance(pred_str, list) and len(pred_str) == len(label_str):
            for index in random.sample(range(len(label_str)), 3):
                print(f'reference: "{label_str[index]}"')
                print(f'predicted: "{pred_str[index]}"')

        else:
            for index in random.sample(range(len(label_str)), 3):
                print(f'reference: "{label_str[index]}"')
                print(f'predicted: "{pred_str}"')

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    # "facebook/wav2vec2-large-xlsr-53" if not last_checkpoint else last_checkpoint, 
    model_name_or_path, 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    gradient_checkpointing=True, 
    ctc_loss_reduction="mean", 
    ctc_zero_infinity=True,
    bos_token_id=processor.tokenizer.bos_token_id,
    eos_token_id=processor.tokenizer.eos_token_id,
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer.get_vocab())
)
# Out:
# loading configuration file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/config.json from cache at /content/cache/1235e742a34b213c61a0cfefc53e513037451cad3a4656601854881890e30aed.74d42a6cfddd289a8d54f606c6d0bc2f8da73e383158b29381eeea7f49cc6364
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-large-xlsr-53",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": true,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "gradient_checkpointing": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 0,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "transformers_version": "4.20.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 40,
#   "xvector_output_dim": 512
# }
#
# loading weights file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/pytorch_model.bin from cache at /content/cache/9adc2f41f44a6fbffefc2703ea1f4775ff462cff8df60dc1c1e3bc15019952ab.1495532fc6b21babd59e495681c1a6267fd457897ec7abe2c051a413770538e9
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at m3hrdadfi/wav2vec2-large-xlsr-persian-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.

# %%
model.freeze_feature_extractor()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1619: FutureWarning: The method `freeze_feature_extractor` is deprecated and will be removed in Transformers v5.Please use the equivalent `freeze_feature_encoder` method instead.
#   FutureWarning,

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir=save_dir,
    group_by_length=True,
    per_device_train_batch_size=10,
    per_device_eval_batch_size=10,
    gradient_accumulation_steps=2,
    evaluation_strategy="steps",
    num_train_epochs=30,
    fp16=True,
    save_steps=1000,
    eval_steps=1000,
    logging_steps=1000,
    learning_rate=1e-4,
    warmup_steps=500,
    save_total_limit=2,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=_common_voice_train,
    eval_dataset=_common_voice_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# Using cuda_amp half precision backend

# %% [markdown]
# ### Training

# %%
print(f"last_checkpoint: {last_checkpoint}")
# Out:
# last_checkpoint: /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/checkpoint-500

# %%
if last_checkpoint:
    print(f"last_checkpoint: {last_checkpoint}")
    train_result = trainer.train(resume_from_checkpoint=last_checkpoint)
else:
    train_result = trainer.train()


metrics = train_result.metrics
max_train_samples = len(_common_voice_train)
metrics["train_samples"] = min(max_train_samples, len(_common_voice_train))

trainer.save_model()

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# Loading model from /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/checkpoint-400.
# last_checkpoint: /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/checkpoint-500
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 527
#   Num Epochs = 10
#   Instantaneous batch size per device = 10
#   Total train batch size (w. parallel, distributed & accumulation) = 20
#   Gradient Accumulation steps = 2
#   Total optimization steps = 260
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 15
#   Continuing training from global step 400
#   Will skip the first 15 epochs then the first 20 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Training completed. Do not forget to share your model on huggingface.co/models =)
#     <div>
#
#       <progress value='400' max='260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [400/260 : < :, Epoch 15/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo
# Configuration saved in /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/config.json
# Model weights saved in /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/pytorch_model.bin
# Feature extractor saved in /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/preprocessor_config.json
# ***** train metrics *****
#   epoch                    =        15.38
#   total_flos               = 1588895724GF
#   train_loss               =          0.0
#   train_runtime            =   0:00:09.84
#   train_samples            =          527
#   train_samples_per_second =      535.074
#   train_steps_per_second   =       26.398

# %%
final_path = "/content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo"

# %%
model = Wav2Vec2ForCTC.from_pretrained(final_path).to("cuda")
processor = Wav2Vec2Processor.from_pretrained(final_path)
# Out:
# loading configuration file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/config.json
# Model config Wav2Vec2Config {
#   "_name_or_path": "m3hrdadfi/wav2vec2-large-xlsr-persian-v2",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": true,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 0,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.20.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 40,
#   "xvector_output_dim": 512
# }
#
# loading weights file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/pytorch_model.bin
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.
# loading feature extractor configuration file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/preprocessor_config.json
# Feature extractor Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }
#
# Didn't find file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/added_tokens.json. We won't load it.
# loading file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/vocab.json
# loading file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/tokenizer_config.json
# loading file None
# loading file /content/drive/MyDrive/wav2vec2-large-xlsr-persian-shemo/special_tokens_map.json

# %% [markdown]
# Now, we will just take the first example of the test set, run it through the model and take the `argmax(...)` of the logits to retrieve the predicted token ids.

# %%
input_dict = processor(_common_voice_test["input_values"][0], return_tensors="pt", padding=True)

logits = model(input_dict.input_values.to("cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)[0]
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.

# %% [markdown]
# We adapted `common_voice_test` quite a bit so that the dataset instance does not contain the original sentence label anymore. Thus, we re-use the original dataset to get the label of the first example.

# %%
common_voice_test_transcription = load_dataset("csv", data_files={"test": "/content/data/shemo/test.csv"}, delimiter="\t")["test"]
# Out:
# Using custom data configuration default-11c85cda03fa3ff8
# Reusing dataset csv (/content/cache/csv/default-11c85cda03fa3ff8/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Finally, we can decode the example.

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(common_voice_test_transcription["sentence"][0].lower())
# Out:
# Prediction:
# ی خان  حما سرگذاشتی داشتی قسمت مایین بود چه میشه کردخدا اینطور می خواست که من تو زندگی حتی یه روز دل خوشی نداشته باشم یه آب راحت از گلوم پایین نره
#
# Reference:
# ای خانوم ما هم سرگذشتی داشتیم قسمت ما این بود چه می شه کرد خدا این طور می خواست که من تو زندگی حتی یه روز دلخوشی نداشته باشم یه آب راحت از گلوم پایین نره

# %%
def map_to_result(batch):
  with torch.no_grad():
    input_values = torch.tensor(batch["input_values"], device="cuda").unsqueeze(0)
    logits = model(input_values).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_str"] = processor.batch_decode(pred_ids)[0]
  batch["text"] = processor.decode(batch["labels"], group_tokens=False)
  
  return batch

# %%
results = _common_voice_test.map(map_to_result, remove_columns=_common_voice_test.column_names)
# Out:
#   0%|          | 0/284 [00:00<?, ?ex/s]

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=results["pred_str"], references=results["text"])))
# Out:
# Test WER: 0.330

# %%
show_random_elements(results)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>تا خیا اون هفتاد و دوم با هم حرف می زنن و اونجا می رن تو مغازه ای به اسم کلریج</td>
#       <td>تا خیابون هفتاد و دوم با هم حرف می زنن و اونجا می رن تو مغازه ای به اسم کلریچ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>شنیدیم امیرشفق جوانی نیازمند اهدائ قلب که سال ها تحت مراقبت و در لیست انتظار ادای عضو قرار داشته  در سماه قبل از این انتظار طولانی خسته و ناامید دست از انتظار می کشه تا با دوستان و نمزدش مهتاب باقیمنده عمرش رو وقت گذرانی کنه و خوش بگذرونه</td>
#       <td>شنیدیم امیرشفق جوانی نیازمند اهدای قلب که سال ها تحت مراقبت و در لیست انتظار اهدای عضو قرار داشته در سه ماه قبل از این انتظار طولانی خسته و ناامید دست از انتظار می کشه تا با دوستان و نامزدش مهتاب باقیمانده عمرش رو وقت گذرانی کنه و خوش بگذرونه</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>من آاریجنام</td>
#       <td>من عالی جناب</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ین صد ئومد</td>
#       <td>به سلامت</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>اون طفل محصون که دیوونه شده رفته پی کارش</td>
#       <td>اون طفل معصوم که دیوونه شده رفته پی کارش</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>من دو رو به خاطر تنبیه نگه نداشتم همر</td>
#       <td>من تو رو بخاطر تنبیه نگه نداشتم هومر</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>حکومت با محدودیت هایی که برای انجام آیین های عزاداری ایجاد کرده است مردم را عاصی کرده و به خیابان ها می کشاند</td>
#       <td>حکومت با محدودیت هایی که برای انجام آیین های عزاداری ایجاد کرده است مردم را عاصی کرده و به خیابان ها می کشاند</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>من جانشین پدر اون شدم یعنی قبل از من پدر امادمازل مارتن در این محله وکالت می کرد و با پدر شما هم دوسته ثمی می بود</td>
#       <td>من جانشین پدر او شدم یعنی قبل از من پدر مادمازل مارتن در این محله وکالت می کرد و با پدر شما هم دوست صمیمی بود</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>طق نداری به خاطر یه لغمنون که برادرم اینجا با ما می خوره مادم سرکوفتش بزنی</td>
#       <td>تو حق نداری به خاطر یه لقمه نون که برادرم اینجا با ما می خوره مدام سرکوفتش بزنی</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>جون شب شده بود ما نتونستیم کشتی رو پیدا کنیم و ناچار بودیم هم با امواج دریا مبارزه کنیم و هم با قرع شدن قایق که سوراغ شدهه</td>
#       <td>چون شب شده بود ما نتونستیم کشتی رو پیدا کنیم و ناچار بودیم هم با امواج دریا مبارزه کنیم و هم با غرق شدن قایق که سوراخ شده بود</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install https://github.com/kpu/kenlm/archive/master.zip 
# !pyctcdecode==0.3.0
# !pip install datasets=2.0.0
# !pip transformers==4.18.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/kpu/kenlm/archive/master.zip
#   Downloading https://github.com/kpu/kenlm/archive/master.zip
#      - 550 kB 4.1 MB/s
# Building wheels for collected packages: kenlm
#   Building wheel for kenlm (setup.py) ... done
#   Created wheel for kenlm: filename=kenlm-0.0.0-cp37-cp37m-linux_x86_64.whl size=2372649 sha256=9432bd951b8aa425ee88e8f056454063ad1bb704cf88793cc7fd7913995d4d7a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ewq2nptv/wheels/3d/aa/02/7b4a2eab5d7a2a9391bd9680dbad6270808a147bc3b7047e4e
# Successfully built kenlm
# Installing collected packages: kenlm
# Successfully installed kenlm-0.0.0
# ERROR: Invalid requirement: 'datasets=2.0.0'
# Hint: = is not a valid operator. Did you mean == ?
# ERROR: unknown command "transformers==4.18.0"

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
processor = Wav2Vec2Processor.from_pretrained(model_name_or_path)
model = Wav2Vec2ForCTC.from_pretrained(model_name_or_path)
# Out:
# loading feature extractor configuration file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/preprocessor_config.json from cache at /content/cache/be9a7bf410a7d0ec32555e6dc9c034f27bbe4d8a054f412c9e96a3e833b3aaf0.fcd266b775b7f33ba9b607a0fee7cc615aeb2eb281586f046280492ea380ae23
# Feature extractor Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }
#
# loading configuration file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/config.json from cache at /content/cache/1235e742a34b213c61a0cfefc53e513037451cad3a4656601854881890e30aed.74d42a6cfddd289a8d54f606c6d0bc2f8da73e383158b29381eeea7f49cc6364
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Model config Wav2Vec2Config {
#   "_name_or_path": "m3hrdadfi/wav2vec2-large-xlsr-persian-v2",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": true,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "gradient_checkpointing": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 0,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "transformers_version": "4.20.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 40,
#   "xvector_output_dim": 512
# }
#
# loading file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/vocab.json from cache at /content/cache/461362fce5b0e1b4136757fea11c57ee75cdc69550d04deb445cb8238ebb97a1.2b1b80bf0b2d9f422d95acb0fd300e3f31dcd3f5766a2e7d6d9a7fa35bcc40ad
# loading file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/tokenizer_config.json from cache at /content/cache/d64dbc4e8c812b2afe08084fc64e5ee8d06400c02afec5b8e876e5e0ec7df007.ea28570bd84cc806dae8a5ad416aa9fb57e169b1bf6fce0386fd890fec53e6a0
# loading file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/special_tokens_map.json from cache at /content/cache/b1917e5b77adaff22f12248ad2e61816238bfc6bcfa639cb354fa89c49b48f52.9d6cd81ef646692fb1c169a880161ea1cb95f49694f220aced9b704b457e51dd
# loading configuration file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/config.json from cache at /content/cache/1235e742a34b213c61a0cfefc53e513037451cad3a4656601854881890e30aed.74d42a6cfddd289a8d54f606c6d0bc2f8da73e383158b29381eeea7f49cc6364
# Model config Wav2Vec2Config {
#   "_name_or_path": "m3hrdadfi/wav2vec2-large-xlsr-persian-v2",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": true,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "gradient_checkpointing": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 0,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "transformers_version": "4.20.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 40,
#   "xvector_output_dim": 512
# }
#
# loading configuration file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/config.json from cache at /content/cache/1235e742a34b213c61a0cfefc53e513037451cad3a4656601854881890e30aed.74d42a6cfddd289a8d54f606c6d0bc2f8da73e383158b29381eeea7f49cc6364
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-large-xlsr-53",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": true,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "gradient_checkpointing": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 0,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "transformers_version": "4.20.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 40,
#   "xvector_output_dim": 512
# }
#
# loading weights file https://huggingface.co/m3hrdadfi/wav2vec2-large-xlsr-persian-v2/resolve/main/pytorch_model.bin from cache at /content/cache/9adc2f41f44a6fbffefc2703ea1f4775ff462cff8df60dc1c1e3bc15019952ab.1495532fc6b21babd59e495681c1a6267fd457897ec7abe2c051a413770538e9
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at m3hrdadfi/wav2vec2-large-xlsr-persian-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.

# %%
from datasets import load_dataset

dataset = load_dataset("hf-internal-testing/librispeech_asr_demo", "clean", split="validation")
dataset
